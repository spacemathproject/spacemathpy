# %%
#-*- coding: utf-8 -*-
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#Rxx
from spacemathpy import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ghfifj,Nc,mi,mj,mS = sp.symbols('g_{hfifj},N_c,m_i,m_j,m_S',positive=True)
WidthHff(ghfifj,Nc,mi,mj,mS)#.factor()
WidthHff(1,1,1,1,np.linspace(120,130,10))
# Out:
#                         _____________________                      3/2
#                        ╱                   2  ⎛                  2⎞
#              2        ╱      ⎛2⋅mᵢ   2⋅m_j⎞   ⎜    ⎛2⋅mᵢ   2⋅m_j⎞ ⎟
# N_c⋅g_{hfifj} ⋅m_S⋅  ╱   4 - ⎜──── - ─────⎟  ⋅⎜4 - ⎜──── + ─────⎟ ⎟
#                    ╲╱        ⎝m_S     m_S ⎠   ⎝    ⎝m_S     m_S ⎠ ⎠
# ──────────────────────────────────────────────────────────────────────
#                                 128⋅π
# array([4.77265899, 4.81688695, 4.86111457, 4.90534187, 4.94956886,
#        4.99379554, 5.03802192, 5.08224801, 5.12647382, 5.17069936])

# %%
#Se necesitan masas de este orden para que esta funcion
#este definida
ft(mS)
ft(np.linspace(350,600,10))
# Out:
#        ⎛      ___________    ⎞
#        ⎜     ╱         2     ⎟
#  2    2⎜    ╱      4⋅mₜ      ⎟
# π ⋅log ⎜   ╱   1 - ─────  + 1⎟
#        ⎜  ╱            2     ⎟
#        ⎝╲╱          m_S      ⎠
# ──────────────────────────────
#                            2
#     ⎛          ___________⎞
#     ⎜         ╱         2 ⎟
#     ⎜        ╱      4⋅mₜ  ⎟
#   4⋅⎜1 -    ╱   1 - ───── ⎟
#     ⎜      ╱            2 ⎟
#     ⎝    ╲╱          m_S  ⎠
# array([ 0.05970251,  0.76951253,  1.87706857,  3.42645747,  5.48223922,
#         8.11718878, 11.41013578, 15.4452574 , 20.31178232, 26.10384738])

# %%
fb(mS)
fb(np.linspace(125,130,10))
# Out:
#        ⎛      ____________    ⎞
#        ⎜     ╱          2     ⎟
#  2    2⎜    ╱      4⋅m_b      ⎟
# π ⋅log ⎜   ╱   1 - ──────  + 1⎟
#        ⎜  ╱            2      ⎟
#        ⎝╲╱          m_S       ⎠
# ───────────────────────────────
#                             2
#     ⎛          ____________⎞
#     ⎜         ╱          2 ⎟
#     ⎜        ╱      4⋅m_b  ⎟
#   4⋅⎜1 -    ╱   1 - ────── ⎟
#     ⎜      ╱            2  ⎟
#     ⎝    ╲╱          m_S   ⎠
# array([235715.3857402 , 239945.52511486, 244232.29402115, 248576.19516613,
#        252977.73347632, 257437.41609767, 261955.75239563, 266533.2539551 ,
#        271170.43458041, 275867.81029535])

# %%
gt(mS)
gt(np.linspace(125,130,10))
# Out:
#     2⎛m_S ⎞
# asin ⎜────⎟
#      ⎝2⋅mₜ⎠
# array([0.13628031, 0.13755328, 0.13883302, 0.14011955, 0.1414129 ,
#        0.14271307, 0.1440201 , 0.14533398, 0.14665475, 0.14798242])

# %%
gb(mS)
gb(np.linspace(125,130,10))
# Out:
#     2⎛ m_S ⎞
# asin ⎜─────⎟
#      ⎝2⋅m_b⎠
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
At(mS)
At(np.linspace(100,1000,10))
# Out:
# ⎧                                        2
# ⎪             2⎛m_S ⎞                 m_S
# ⎪         asin ⎜────⎟            for ───── ≤ 1
# ⎪              ⎝2⋅mₜ⎠                    2
# ⎪                                    4⋅mₜ
# ⎪
# ⎪       ⎛      ___________    ⎞
# ⎪       ⎜     ╱         2     ⎟
# ⎪ 2    2⎜    ╱      4⋅mₜ      ⎟
# ⎪π ⋅log ⎜   ╱   1 - ─────  + 1⎟
# ⎨       ⎜  ╱            2     ⎟
# ⎪       ⎝╲╱          m_S      ⎠
# ⎪──────────────────────────────    otherwise
# ⎪                           2
# ⎪    ⎛          ___________⎞
# ⎪    ⎜         ╱         2 ⎟
# ⎪    ⎜        ╱      4⋅mₜ  ⎟
# ⎪  4⋅⎜1 -    ╱   1 - ───── ⎟
# ⎪    ⎜      ╱            2 ⎟
# ⎪    ⎝    ╲╱          m_S  ⎠
# ⎩
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:59: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mtop**2)))**2;
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return (1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(np.pi))**2;#MODIFICADO#(-sp.I*np.pi)
# array([8.57518738e-02, 3.78790552e-01, 1.09651969e+00, 1.62207849e+00,
#        9.35080952e+00, 2.61038474e+01, 5.61964263e+01, 1.04756812e+02,
#        1.77708529e+02, 2.81767017e+02])

# %%
Ab(mS)
Ab(np.linspace(100,1000,10))
# Out:
# ⎧                                         2
# ⎪             2⎛ m_S ⎞                 m_S
# ⎪         asin ⎜─────⎟            for ────── ≤ 1
# ⎪              ⎝2⋅m_b⎠                     2
# ⎪                                     4⋅m_b
# ⎪
# ⎪       ⎛      ____________    ⎞
# ⎪       ⎜     ╱          2     ⎟
# ⎪ 2    2⎜    ╱      4⋅m_b      ⎟
# ⎪π ⋅log ⎜   ╱   1 - ──────  + 1⎟
# ⎨       ⎜  ╱            2      ⎟
# ⎪       ⎝╲╱          m_S       ⎠
# ⎪───────────────────────────────    otherwise
# ⎪                            2
# ⎪    ⎛          ____________⎞
# ⎪    ⎜         ╱          2 ⎟
# ⎪    ⎜        ╱      4⋅m_b  ⎟
# ⎪  4⋅⎜1 -    ╱   1 - ────── ⎟
# ⎪    ⎜      ╱            2  ⎟
# ⎪    ⎝    ╲╱          m_S   ⎠
# ⎩
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# array([9.62511461e+04, 1.54995104e+06, 7.85594656e+06, 2.48389812e+07,
#        6.06536960e+07, 1.25784629e+08, 2.33046217e+08, 3.97582792e+08,
#        6.36868585e+08, 9.70707724e+08])

# %%
#mtop = sp.symbols('m_t',positive=True)
Ft(mS)#.simplify().subs(mtop,0.1)
Ft(np.linspace(120,130,10))
# Out:
#        ⎛            ⎛⎧                                        2    ⎞    ⎞
#        ⎜            ⎜⎪             2⎛m_S ⎞                 m_S     ⎟    ⎟
#        ⎜            ⎜⎪         asin ⎜────⎟            for ───── ≤ 1⎟    ⎟
#        ⎜            ⎜⎪              ⎝2⋅mₜ⎠                    2    ⎟    ⎟
#        ⎜            ⎜⎪                                    4⋅mₜ     ⎟    ⎟
#        ⎜            ⎜⎪                                             ⎟    ⎟
#        ⎜            ⎜⎪       ⎛      ___________    ⎞               ⎟    ⎟
#        ⎜            ⎜⎪       ⎜     ╱         2     ⎟               ⎟    ⎟
#        ⎜⎛        2⎞ ⎜⎪ 2    2⎜    ╱      4⋅mₜ      ⎟               ⎟    ⎟
#      2 ⎜⎜    4⋅mₜ ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ─────  + 1⎟               ⎟    ⎟
# -8⋅mₜ ⋅⎜⎜1 - ─────⎟⋅⎜⎨       ⎜  ╱            2     ⎟               ⎟ + 1⎟
#        ⎜⎜        2⎟ ⎜⎪       ⎝╲╱          m_S      ⎠               ⎟    ⎟
#        ⎜⎝     m_S ⎠ ⎜⎪──────────────────────────────    otherwise  ⎟    ⎟
#        ⎜            ⎜⎪                           2                 ⎟    ⎟
#        ⎜            ⎜⎪    ⎛          ___________⎞                  ⎟    ⎟
#        ⎜            ⎜⎪    ⎜         ╱         2 ⎟                  ⎟    ⎟
#        ⎜            ⎜⎪    ⎜        ╱      4⋅mₜ  ⎟                  ⎟    ⎟
#        ⎜            ⎜⎪  4⋅⎜1 -    ╱   1 - ───── ⎟                  ⎟    ⎟
#        ⎜            ⎜⎪    ⎜      ╱            2 ⎟                  ⎟    ⎟
#        ⎜            ⎜⎪    ⎝    ╲╱          m_S  ⎠                  ⎟    ⎟
#        ⎝            ⎝⎩                                             ⎠    ⎠
# ──────────────────────────────────────────────────────────────────────────
#                                       2
#                                    m_S
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return (1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(np.pi))**2;#MODIFICADO#(-sp.I*np.pi)
# array([-1.37261586, -1.37338622, -1.37416526, -1.37495301, -1.37574953,
#        -1.37655487, -1.37736908, -1.37819221, -1.37902433, -1.37986547])

# %%
Fb(mS).simplify()#.subs(mtop,0.1)
Fb(np.linspace(120,130,10))
# Out:
# ⎧               2 ⎛   2   ⎛   2        2⎞     2⎛ m_S ⎞⎞
# ⎪         -8⋅m_b ⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin ⎜─────⎟⎟                    2
# ⎪                 ⎝                            ⎝2⋅m_b⎠⎠                 m_S
# ⎪         ──────────────────────────────────────────────           for ──────
# ⎪                                 4                                         2
# ⎪                              m_S                                     4⋅m_b
# ⎪
# ⎪        ⎛                           ⎛         _______________⎞⎞
# ⎪        ⎜                           ⎜        ╱    2        2 ⎟⎟
# ⎪        ⎜     2 ⎛   2        2⎞    2⎜m_S + ╲╱  m_S  - 4⋅m_b  ⎟⎟
# ⎨        ⎜    π ⋅⎝m_S  - 4⋅m_b ⎠⋅log ⎜────────────────────────⎟⎟
# ⎪      2 ⎜                           ⎝          m_S           ⎠⎟
# ⎪-8⋅m_b ⋅⎜1 + ─────────────────────────────────────────────────⎟
# ⎪        ⎜                                           2         ⎟
# ⎪        ⎜                ⎛          _______________⎞          ⎟
# ⎪        ⎜                ⎜         ╱    2        2 ⎟          ⎟
# ⎪        ⎝              4⋅⎝-m_S + ╲╱  m_S  - 4⋅m_b  ⎠          ⎠
# ⎪────────────────────────────────────────────────────────────────    otherwise
# ⎪                                 2
# ⎪                              m_S
# ⎩
#
#
#
#
# ≤ 1
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# array([-1933.03360523, -1969.38548441, -2006.07245251, -2043.09450823,
#        -2080.45165032, -2118.1438776 , -2156.17118893, -2194.53358322,
#        -2233.23105944, -2272.2636166 ])

# %%
ghtt,ghbb = sp.symbols('g_{htt},g_{hbb}',real=True)
AHgg(ghtt,ghbb,mS).simplify()
AHgg(0.2,0.1,np.linspace(120,130,10))
# Out:
#        ⎛              ⎛             ⎛⎧
#        ⎜              ⎜             ⎜⎪             2⎛ m_S ⎞                 m_
#        ⎜              ⎜             ⎜⎪         asin ⎜─────⎟            for ───
#        ⎜              ⎜             ⎜⎪              ⎝2⋅m_b⎠
#        ⎜              ⎜             ⎜⎪                                     4⋅m
#        ⎜              ⎜             ⎜⎪
#        ⎜              ⎜             ⎜⎪       ⎛      ____________    ⎞
#        ⎜              ⎜             ⎜⎪       ⎜     ╱          2     ⎟
#        ⎜              ⎜⎛         2⎞ ⎜⎪ 2    2⎜    ╱      4⋅m_b      ⎟
#        ⎜              ⎜⎜    4⋅m_b ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ──────  + 1⎟
#        ⎜8⋅g_{hbb}⋅m_b⋅⎜⎜1 - ──────⎟⋅⎜⎨       ⎜  ╱            2      ⎟
#        ⎜              ⎜⎜        2 ⎟ ⎜⎪       ⎝╲╱          m_S       ⎠
#        ⎜              ⎜⎝     m_S  ⎠ ⎜⎪───────────────────────────────    other
#        ⎜              ⎜             ⎜⎪                            2
#        ⎜              ⎜             ⎜⎪    ⎛      ____________    ⎞
#        ⎜              ⎜             ⎜⎪    ⎜     ╱          2     ⎟
#        ⎜              ⎜             ⎜⎪    ⎜    ╱      4⋅m_b      ⎟
#        ⎜              ⎜             ⎜⎪  4⋅⎜   ╱   1 - ──────  - 1⎟
#        ⎜              ⎜             ⎜⎪    ⎜  ╱            2      ⎟
#        ⎜              ⎜             ⎜⎪    ⎝╲╱          m_S       ⎠
#        ⎜              ⎝             ⎝⎩
# -2⋅m_W⋅⎜──────────────────────────────────────────────────────────────────────
#        ⎜                                           2
#        ⎝                                        m_S
#
#  2     ⎞    ⎞                ⎛            ⎛⎧
# S      ⎟    ⎟                ⎜            ⎜⎪             2⎛m_S ⎞
# ─── ≤ 1⎟    ⎟                ⎜            ⎜⎪         asin ⎜────⎟            fo
#   2    ⎟    ⎟                ⎜            ⎜⎪              ⎝2⋅mₜ⎠
# _b     ⎟    ⎟                ⎜            ⎜⎪
#        ⎟    ⎟                ⎜            ⎜⎪
#        ⎟    ⎟                ⎜            ⎜⎪       ⎛      ___________    ⎞
#        ⎟    ⎟                ⎜            ⎜⎪       ⎜     ╱         2     ⎟
#        ⎟    ⎟                ⎜⎛        2⎞ ⎜⎪ 2    2⎜    ╱      4⋅mₜ      ⎟
#        ⎟    ⎟                ⎜⎜    4⋅mₜ ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ─────  + 1⎟
#        ⎟ + 1⎟   8⋅g_{htt}⋅mₜ⋅⎜⎜1 - ─────⎟⋅⎜⎨       ⎜  ╱            2     ⎟
#        ⎟    ⎟                ⎜⎜        2⎟ ⎜⎪       ⎝╲╱          m_S      ⎠
# wise   ⎟    ⎟                ⎜⎝     m_S ⎠ ⎜⎪──────────────────────────────
#        ⎟    ⎟                ⎜            ⎜⎪                           2
#        ⎟    ⎟                ⎜            ⎜⎪    ⎛      ___________    ⎞
#        ⎟    ⎟                ⎜            ⎜⎪    ⎜     ╱         2     ⎟
#        ⎟    ⎟                ⎜            ⎜⎪    ⎜    ╱      4⋅mₜ      ⎟
#        ⎟    ⎟                ⎜            ⎜⎪  4⋅⎜   ╱   1 - ─────  - 1⎟
#        ⎟    ⎟                ⎜            ⎜⎪    ⎜  ╱            2     ⎟
#        ⎟    ⎟                ⎜            ⎜⎪    ⎝╲╱          m_S      ⎠
#        ⎠    ⎠                ⎝            ⎝⎩
# ───────────── + ──────────────────────────────────────────────────────────────
#                                                          2
#                                                       m_S
#
#       2    ⎞    ⎞⎞
#    m_S     ⎟    ⎟⎟
# r ───── ≤ 1⎟    ⎟⎟
#       2    ⎟    ⎟⎟
#   4⋅mₜ     ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟ + 1⎟⎟
#            ⎟    ⎟⎟
# otherwise  ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎟    ⎟⎟
#            ⎠    ⎠⎟
# ─────────────────⎟
#                  ⎟
#                  ⎠
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return (1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(np.pi))**2;#MODIFICADO#(-sp.I*np.pi)
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# array([-7434.48005836, -7574.28535433, -7715.37936539, -7857.76208657,
#        -8001.43351308, -8146.39364039, -8292.64246412, -8440.17998012,
#        -8589.0061844 , -8739.12107313])

# %%
WidthHgg(ghtt,ghbb,mS).simplify()
plt.loglog(np.linspace(125,1000,100),WidthHgg(0.2,0.1,np.linspace(125,1000,100)))
# Out:
#
#               │              ⎛             ⎛⎧
#               │              ⎜             ⎜⎪             2⎛ m_S ⎞
#               │              ⎜             ⎜⎪         asin ⎜─────⎟
#               │              ⎜             ⎜⎪              ⎝2⋅m_b⎠
#               │              ⎜             ⎜⎪
#               │              ⎜             ⎜⎪
#               │              ⎜             ⎜⎪       ⎛      ____________    ⎞
#               │              ⎜             ⎜⎪       ⎜     ╱          2     ⎟
#               │              ⎜⎛         2⎞ ⎜⎪ 2    2⎜    ╱      4⋅m_b      ⎟
#               │              ⎜⎜    4⋅m_b ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ──────  + 1⎟
#               │8⋅g_{hbb}⋅m_b⋅⎜⎜1 - ──────⎟⋅⎜⎨       ⎜  ╱            2      ⎟
#               │              ⎜⎜        2 ⎟ ⎜⎪       ⎝╲╱          m_S       ⎠
#               │              ⎜⎝     m_S  ⎠ ⎜⎪───────────────────────────────
#               │              ⎜             ⎜⎪                            2
#               │              ⎜             ⎜⎪    ⎛      ____________    ⎞
#               │              ⎜             ⎜⎪    ⎜     ╱          2     ⎟
#               │              ⎜             ⎜⎪    ⎜    ╱      4⋅m_b      ⎟
#               │              ⎜             ⎜⎪  4⋅⎜   ╱   1 - ──────  - 1⎟
#               │              ⎜             ⎜⎪    ⎜  ╱            2      ⎟
#               │              ⎜             ⎜⎪    ⎝╲╱          m_S       ⎠
#        2    3 │              ⎝             ⎝⎩
# \alphaₛ ⋅m_S ⋅│───────────────────────────────────────────────────────────────
#               │                                           2
#               │                                        m_S
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#         2     ⎞    ⎞                ⎛            ⎛⎧
#      m_S      ⎟    ⎟                ⎜            ⎜⎪             2⎛m_S ⎞
# for ────── ≤ 1⎟    ⎟                ⎜            ⎜⎪         asin ⎜────⎟
#          2    ⎟    ⎟                ⎜            ⎜⎪              ⎝2⋅mₜ⎠
#     4⋅m_b     ⎟    ⎟                ⎜            ⎜⎪
#               ⎟    ⎟                ⎜            ⎜⎪
#               ⎟    ⎟                ⎜            ⎜⎪       ⎛      ___________
#               ⎟    ⎟                ⎜            ⎜⎪       ⎜     ╱         2
#               ⎟    ⎟                ⎜⎛        2⎞ ⎜⎪ 2    2⎜    ╱      4⋅mₜ
#               ⎟    ⎟                ⎜⎜    4⋅mₜ ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ─────  +
#               ⎟ + 1⎟   8⋅g_{htt}⋅mₜ⋅⎜⎜1 - ─────⎟⋅⎜⎨       ⎜  ╱            2
#               ⎟    ⎟                ⎜⎜        2⎟ ⎜⎪       ⎝╲╱          m_S
#   otherwise   ⎟    ⎟                ⎜⎝     m_S ⎠ ⎜⎪───────────────────────────
#               ⎟    ⎟                ⎜            ⎜⎪
#               ⎟    ⎟                ⎜            ⎜⎪    ⎛      ___________    ⎞
#               ⎟    ⎟                ⎜            ⎜⎪    ⎜     ╱         2     ⎟
#               ⎟    ⎟                ⎜            ⎜⎪    ⎜    ╱      4⋅mₜ      ⎟
#               ⎟    ⎟                ⎜            ⎜⎪  4⋅⎜   ╱   1 - ─────  - 1⎟
#               ⎟    ⎟                ⎜            ⎜⎪    ⎜  ╱            2     ⎟
#               ⎟    ⎟                ⎜            ⎜⎪    ⎝╲╱          m_S      ⎠
#               ⎠    ⎠                ⎝            ⎝⎩
# ──────────────────── + ───────────────────────────────────────────────────────
#                                                                 2
#                                                              m_S
# ──────────────────────────────────────────────────────────────────────────────
#                3
#           128⋅π
#
#                          2
#              2    ⎞    ⎞│
#           m_S     ⎟    ⎟│
#      for ───── ≤ 1⎟    ⎟│
#              2    ⎟    ⎟│
#          4⋅mₜ     ⎟    ⎟│
#                   ⎟    ⎟│
#   ⎞               ⎟    ⎟│
#   ⎟               ⎟    ⎟│
#   ⎟               ⎟    ⎟│
#  1⎟               ⎟    ⎟│
#   ⎟               ⎟ + 1⎟│
#   ⎠               ⎟    ⎟│
# ───    otherwise  ⎟    ⎟│
# 2                 ⎟    ⎟│
#                   ⎟    ⎟│
#                   ⎟    ⎟│
#                   ⎟    ⎟│
#                   ⎟    ⎟│
#                   ⎟    ⎟│
#                   ⎟    ⎟│
#                   ⎠    ⎠│
# ────────────────────────│
#                         │
#                         │
# ──────────────────────────
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:59: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mtop**2)))**2;
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return (1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(np.pi))**2;#MODIFICADO#(-sp.I*np.pi)
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;

# %%
Aht(ghtt,mS).simplify()
Aht(0.1,np.linspace(120,130,10))
# Out:
# ⎧                    2        ⎛   2   ⎛   2       2⎞     2⎛m_S ⎞⎞
# ⎪         -64⋅g_{htt} ⋅m_W⋅mₜ⋅⎜m_S  + ⎝m_S  - 4⋅mₜ ⎠⋅asin ⎜────⎟⎟
# ⎪                             ⎝                           ⎝2⋅mₜ⎠⎠
# ⎪         ────────────────────────────────────────────────────────           f
# ⎪                                       4
# ⎪                                  3⋅m_S
# ⎪
# ⎪                    ⎛                          ⎛         ______________⎞⎞
# ⎪                    ⎜                          ⎜        ╱    2       2 ⎟⎟
# ⎪                    ⎜     2 ⎛   2       2⎞    2⎜m_S + ╲╱  m_S  - 4⋅mₜ  ⎟⎟
# ⎨                    ⎜    π ⋅⎝m_S  - 4⋅mₜ ⎠⋅log ⎜───────────────────────⎟⎟
# ⎪           2        ⎜                          ⎝          m_S          ⎠⎟
# ⎪-64⋅g_{htt} ⋅m_W⋅mₜ⋅⎜1 + ───────────────────────────────────────────────⎟
# ⎪                    ⎜                                         2         ⎟
# ⎪                    ⎜               ⎛          ______________⎞          ⎟
# ⎪                    ⎜               ⎜         ╱    2       2 ⎟          ⎟
# ⎪                    ⎝             4⋅⎝-m_S + ╲╱  m_S  - 4⋅mₜ  ⎠          ⎠
# ⎪──────────────────────────────────────────────────────────────────────────
# ⎪                                       2
# ⎪                                  3⋅m_S
# ⎩
#
#
#        2
#     m_S
# or ───── ≤ 1
#        2
#    4⋅mₜ
#
#
#
#
#
#
#
#
#
#
#
#  otherwise
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return (1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(np.pi))**2;#MODIFICADO#(-sp.I*np.pi)
# array([-0.01698585, -0.01699539, -0.01700503, -0.01701478, -0.01702463,
#        -0.0170346 , -0.01704467, -0.01705486, -0.01706516, -0.01707557])

# %%
Ahb(ghbb,mS).simplify()
Ahb(0.1,np.linspace(120,130,10))
# Out:
# ⎧                    2         ⎛   2   ⎛   2        2⎞     2⎛ m_S ⎞⎞
# ⎪         -16⋅g_{hbb} ⋅m_W⋅m_b⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin ⎜─────⎟⎟
# ⎪                              ⎝                            ⎝2⋅m_b⎠⎠
# ⎪         ───────────────────────────────────────────────────────────
# ⎪                                         4
# ⎪                                    3⋅m_S
# ⎪
# ⎪                     ⎛                           ⎛         _______________⎞⎞
# ⎪                     ⎜                           ⎜        ╱    2        2 ⎟⎟
# ⎪                     ⎜     2 ⎛   2        2⎞    2⎜m_S + ╲╱  m_S  - 4⋅m_b  ⎟⎟
# ⎨                     ⎜    π ⋅⎝m_S  - 4⋅m_b ⎠⋅log ⎜────────────────────────⎟⎟
# ⎪           2         ⎜                           ⎝          m_S           ⎠⎟
# ⎪-16⋅g_{hbb} ⋅m_W⋅m_b⋅⎜1 + ─────────────────────────────────────────────────⎟
# ⎪                     ⎜                                           2         ⎟
# ⎪                     ⎜                ⎛          _______________⎞          ⎟
# ⎪                     ⎜                ⎜         ╱    2        2 ⎟          ⎟
# ⎪                     ⎝              4⋅⎝-m_S + ╲╱  m_S  - 4⋅m_b  ⎠          ⎠
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                         2
# ⎪                                    3⋅m_S
# ⎩
#
#
#           2
#        m_S
#   for ────── ≤ 1
#            2
#       4⋅m_b
#
#
#
#
#
#
#
#
#
#
#
#     otherwise
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# array([-247.80750902, -252.46768078, -257.17080967, -261.9168955 ,
#        -266.70593812, -271.53793738, -276.41289313, -281.33080524,
#        -286.29167357, -291.29549799])

# %%
Af(ghtt,ghbb,mS).simplify()
Af(0.1,0.1,np.linspace(120,130,10))
# Out:
#                       ⎛             ⎛⎧
#                       ⎜             ⎜⎪             2⎛ m_S ⎞                 m_
#                       ⎜             ⎜⎪         asin ⎜─────⎟            for ───
#                       ⎜             ⎜⎪              ⎝2⋅m_b⎠
#                       ⎜             ⎜⎪                                     4⋅m
#                       ⎜             ⎜⎪
#                       ⎜             ⎜⎪       ⎛      ____________    ⎞
#                       ⎜             ⎜⎪       ⎜     ╱          2     ⎟
#                       ⎜⎛         2⎞ ⎜⎪ 2    2⎜    ╱      4⋅m_b      ⎟
#             2         ⎜⎜    4⋅m_b ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ──────  + 1⎟
#   16⋅g_{hbb} ⋅m_W⋅m_b⋅⎜⎜1 - ──────⎟⋅⎜⎨       ⎜  ╱            2      ⎟
#                       ⎜⎜        2 ⎟ ⎜⎪       ⎝╲╱          m_S       ⎠
#                       ⎜⎝     m_S  ⎠ ⎜⎪───────────────────────────────    other
#                       ⎜             ⎜⎪                            2
#                       ⎜             ⎜⎪    ⎛      ____________    ⎞
#                       ⎜             ⎜⎪    ⎜     ╱          2     ⎟
#                       ⎜             ⎜⎪    ⎜    ╱      4⋅m_b      ⎟
#                       ⎜             ⎜⎪  4⋅⎜   ╱   1 - ──────  - 1⎟
#                       ⎜             ⎜⎪    ⎜  ╱            2      ⎟
#                       ⎜             ⎜⎪    ⎝╲╱          m_S       ⎠
#                       ⎝             ⎝⎩
# - ────────────────────────────────────────────────────────────────────────────
#                                                  2
#                                             3⋅m_S
#
#  2     ⎞    ⎞                      ⎛            ⎛⎧
# S      ⎟    ⎟                      ⎜            ⎜⎪             2⎛m_S ⎞
# ─── ≤ 1⎟    ⎟                      ⎜            ⎜⎪         asin ⎜────⎟
#   2    ⎟    ⎟                      ⎜            ⎜⎪              ⎝2⋅mₜ⎠
# _b     ⎟    ⎟                      ⎜            ⎜⎪
#        ⎟    ⎟                      ⎜            ⎜⎪
#        ⎟    ⎟                      ⎜            ⎜⎪       ⎛      ___________
#        ⎟    ⎟                      ⎜            ⎜⎪       ⎜     ╱         2
#        ⎟    ⎟                      ⎜⎛        2⎞ ⎜⎪ 2    2⎜    ╱      4⋅mₜ
#        ⎟    ⎟             2        ⎜⎜    4⋅mₜ ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ─────  +
#        ⎟ + 1⎟   64⋅g_{htt} ⋅m_W⋅mₜ⋅⎜⎜1 - ─────⎟⋅⎜⎨       ⎜  ╱            2
#        ⎟    ⎟                      ⎜⎜        2⎟ ⎜⎪       ⎝╲╱          m_S
# wise   ⎟    ⎟                      ⎜⎝     m_S ⎠ ⎜⎪────────────────────────────
#        ⎟    ⎟                      ⎜            ⎜⎪                           2
#        ⎟    ⎟                      ⎜            ⎜⎪    ⎛      ___________    ⎞
#        ⎟    ⎟                      ⎜            ⎜⎪    ⎜     ╱         2     ⎟
#        ⎟    ⎟                      ⎜            ⎜⎪    ⎜    ╱      4⋅mₜ      ⎟
#        ⎟    ⎟                      ⎜            ⎜⎪  4⋅⎜   ╱   1 - ─────  - 1⎟
#        ⎟    ⎟                      ⎜            ⎜⎪    ⎜  ╱            2     ⎟
#        ⎟    ⎟                      ⎜            ⎜⎪    ⎝╲╱          m_S      ⎠
#        ⎠    ⎠                      ⎝            ⎝⎩
# ───────────── - ──────────────────────────────────────────────────────────────
#                                                              2
#                                                         3⋅m_S
#
#             2    ⎞    ⎞
#          m_S     ⎟    ⎟
#     for ───── ≤ 1⎟    ⎟
#             2    ⎟    ⎟
#         4⋅mₜ     ⎟    ⎟
#                  ⎟    ⎟
#  ⎞               ⎟    ⎟
#  ⎟               ⎟    ⎟
#  ⎟               ⎟    ⎟
# 1⎟               ⎟    ⎟
#  ⎟               ⎟ + 1⎟
#  ⎠               ⎟    ⎟
# ──    otherwise  ⎟    ⎟
#                  ⎟    ⎟
#                  ⎟    ⎟
#                  ⎟    ⎟
#                  ⎟    ⎟
#                  ⎟    ⎟
#                  ⎟    ⎟
#                  ⎟    ⎟
#                  ⎠    ⎠
# ───────────────────────
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return (1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(np.pi))**2;#MODIFICADO#(-sp.I*np.pi)
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# array([-247.82449487, -252.48467617, -257.18781469, -261.93391027,
#        -266.72296275, -271.55497198, -276.42993781, -281.3478601 ,
#        -286.30873873, -291.31257355])

# %%
fW(mS)
#Esta función no esta definda en este rango 
fW(np.linspace(120,130,10))
# Out:
#                      ⎛      ____________    ⎞
#                      ⎜     ╱          2     ⎟
#                      ⎜    ╱      4⋅m_W      ⎟
#                      ⎜   ╱   1 - ──────  + 1⎟
#                      ⎜  ╱            2      ⎟
#                     2⎜╲╱          m_S       ⎟
# 2.46740110027234⋅log ⎜──────────────────────⎟
#                      ⎜          ____________⎟
#                      ⎜         ╱          2 ⎟
#                      ⎜        ╱      4⋅m_W  ⎟
#                      ⎜1 -    ╱   1 - ────── ⎟
#                      ⎜      ╱            2  ⎟
#                      ⎝    ╲╱          m_S   ⎠
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:160: RuntimeWarning: invalid value encountered in sqrt
#   return (1.0/4.0)*(np.log((1+np.sqrt(1-((4*mWp**2)/(mS**2))))/(1-np.sqrt(1-((4*mWp**2)/(mS**2)))))*(np.pi))**2; #######MODIFICADO#########(-sp.I*np.pi)
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
gW(mS)
gW(np.linspace(120,130,10))
# Out:
#     2⎛ m_S ⎞
# asin ⎜─────⎟
#      ⎝2⋅m_W⎠
# array([0.71019667, 0.72791606, 0.74607247, 0.76468432, 0.78377145,
#        0.80335522, 0.82345874, 0.84410703, 0.86532726, 0.887149  ])

# %%
AW(mS)
AW(np.linspace(120,130,10))
# Out:
# ⎧                                                       2
# ⎪                    2⎛ m_S ⎞                        m_S
# ⎪                asin ⎜─────⎟                   for ────── ≤ 1
# ⎪                     ⎝2⋅m_W⎠                            2
# ⎪                                                   4⋅m_W
# ⎪
# ⎪                     ⎛      ____________    ⎞
# ⎪                     ⎜     ╱          2     ⎟
# ⎪                     ⎜    ╱      4⋅m_W      ⎟
# ⎨                     ⎜   ╱   1 - ──────  + 1⎟
# ⎪                     ⎜  ╱            2      ⎟
# ⎪                    2⎜╲╱          m_S       ⎟
# ⎪2.46740110027234⋅log ⎜──────────────────────⎟    otherwise
# ⎪                     ⎜          ____________⎟
# ⎪                     ⎜         ╱          2 ⎟
# ⎪                     ⎜        ╱      4⋅m_W  ⎟
# ⎪                     ⎜1 -    ╱   1 - ────── ⎟
# ⎪                     ⎜      ╱            2  ⎟
# ⎩                     ⎝    ╲╱          m_S   ⎠
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:160: RuntimeWarning: invalid value encountered in sqrt
#   return (1.0/4.0)*(np.log((1+np.sqrt(1-((4*mWp**2)/(mS**2))))/(1-np.sqrt(1-((4*mWp**2)/(mS**2)))))*(np.pi))**2; #######MODIFICADO#########(-sp.I*np.pi)
# array([0.71019667, 0.72791606, 0.74607247, 0.76468432, 0.78377145,
#        0.80335522, 0.82345874, 0.84410703, 0.86532726, 0.887149  ])

# %%
FW(mS).simplify()
FW(np.linspace(120,130,10))
# Out:
# ⎧                  ⎛   4        2    2         2 ⎛   2        2⎞     2⎛ m_S ⎞⎞
# ⎪                2⋅⎜m_S  + 6⋅m_S ⋅m_W  + 12⋅m_W ⋅⎝m_S  - 2⋅m_W ⎠⋅asin ⎜─────⎟⎟
# ⎪                  ⎝                                                  ⎝2⋅m_W⎠⎠
# ⎪                ─────────────────────────────────────────────────────────────
# ⎪                                                4
# ⎪                                             m_S
# ⎪
# ⎪  ⎛                                                               ⎛
# ⎨  ⎜                                                               ⎜         ╱
# ⎪  ⎜   4        2    2                       2 ⎛   2        2⎞    2⎜-m_S - ╲╱
# ⎪2⋅⎜m_S  + 6⋅m_S ⋅m_W  + 29.6088132032681⋅m_W ⋅⎝m_S  - 2⋅m_W ⎠⋅log ⎜──────────
# ⎪  ⎜                                                               ⎜
# ⎪  ⎜                                                               ⎜         ╱
# ⎪  ⎝                                                               ⎝-m_S + ╲╱
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                                4
# ⎩                                             m_S
#
#
#                            2
#                         m_S
#                    for ────── ≤ 1
#                             2
#                        4⋅m_W
#
# _______________⎞⎞
#     2        2 ⎟⎟
#  m_S  - 4⋅m_W  ⎟⎟
# ───────────────⎟⎟
# _______________⎟⎟
#     2        2 ⎟⎟
#  m_S  - 4⋅m_W  ⎠⎠
# ─────────────────    otherwise
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:160: RuntimeWarning: invalid value encountered in sqrt
#   return (1.0/4.0)*(np.log((1+np.sqrt(1-((4*mWp**2)/(mS**2))))/(1-np.sqrt(1-((4*mWp**2)/(mS**2)))))*(np.pi))**2; #######MODIFICADO#########(-sp.I*np.pi)
# array([8.16913459, 8.20180606, 8.2354727 , 8.27018378, 8.3059925 ,
#        8.34295642, 8.38113795, 8.42060494, 8.46143136, 8.50369801])

# %%
ghWW = sp.symbols('g_{hWW}',real=True)
AhW(ghWW,mS).simplify()
AhW(0.1,np.linspace(120,130,10))
# Out:
# ⎧                          ⎛   4        2    2         2 ⎛   2        2⎞     2
# ⎪                2⋅g_{hWW}⋅⎜m_S  + 6⋅m_S ⋅m_W  + 12⋅m_W ⋅⎝m_S  - 2⋅m_W ⎠⋅asin
# ⎪                          ⎝
# ⎪                ─────────────────────────────────────────────────────────────
# ⎪                                                  4
# ⎪                                               m_S ⋅m_W
# ⎪
# ⎪          ⎛                                                               ⎛
# ⎨          ⎜                                                               ⎜
# ⎪          ⎜   4        2    2                       2 ⎛   2        2⎞    2⎜-m
# ⎪2⋅g_{hWW}⋅⎜m_S  + 6⋅m_S ⋅m_W  + 29.6088132032681⋅m_W ⋅⎝m_S  - 2⋅m_W ⎠⋅log ⎜──
# ⎪          ⎜                                                               ⎜
# ⎪          ⎜                                                               ⎜
# ⎪          ⎝                                                               ⎝-m
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                                  4
# ⎩                                               m_S ⋅m_W
#
# ⎛ m_S ⎞⎞
# ⎜─────⎟⎟                           2
# ⎝2⋅m_W⎠⎠                        m_S
# ────────                   for ────── ≤ 1
#                                     2
#                                4⋅m_W
#
#         _______________⎞⎞
#        ╱    2        2 ⎟⎟
# _S - ╲╱  m_S  - 4⋅m_W  ⎟⎟
# ───────────────────────⎟⎟
#         _______________⎟⎟
#        ╱    2        2 ⎟⎟
# _S + ╲╱  m_S  - 4⋅m_W  ⎠⎠
# ─────────────────────────    otherwise
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:160: RuntimeWarning: invalid value encountered in sqrt
#   return (1.0/4.0)*(np.log((1+np.sqrt(1-((4*mWp**2)/(mS**2))))/(1-np.sqrt(1-((4*mWp**2)/(mS**2)))))*(np.pi))**2; #######MODIFICADO#########(-sp.I*np.pi)
# array([0.01016327, 0.01020392, 0.0102458 , 0.01028899, 0.01033354,
#        0.01037952, 0.01042702, 0.01047613, 0.01052692, 0.0105795 ])

# %%
mCH = sp.symbols(r'm_{H^{\pm}}',positive=True)
fH(mCH,mS).simplify()
fH(200.0,np.linspace(120,130,10))
# Out:
#        ⎛          ________________________⎞
#        ⎜         ╱    2                 2 ⎟
#  2    2⎜-m_S - ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎟
# π ⋅log ⎜──────────────────────────────────⎟
#        ⎜          ________________________⎟
#        ⎜         ╱    2                 2 ⎟
#        ⎝-m_S + ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎠
# ───────────────────────────────────────────
#                      4
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mCH**2)/(mS**2))))/(1-np.sqrt(1-((4*mCH**2)/(mS**2)))))*(-sp.I*np.pi))**2;#######MODIFICADO#########
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], dtype=object)

# %%
gH(mCH,mS)
gH(200.0,np.linspace(120,130,10))
# Out:
#     2⎛     m_S      ⎞
# asin ⎜──────────────⎟
#      ⎝2⋅m_{H__{\pm}}⎠
# array([0.09283761, 0.09462139, 0.09642381, 0.09824495, 0.10008488,
#        0.10194366, 0.10382137, 0.10571807, 0.10763385, 0.10956876])

# %%
AH(mCH,mS).simplify()
AH(200.0,np.linspace(120,130,10))
# Out:
# ⎧                                                          2
# ⎪               2⎛     m_S      ⎞                       m_S
# ⎪           asin ⎜──────────────⎟             for ─────────────── ≤ 1
# ⎪                ⎝2⋅m_{H__{\pm}}⎠                               2
# ⎪                                                 4⋅m_{H__{\pm}}
# ⎪
# ⎪       ⎛          ________________________⎞
# ⎨       ⎜         ╱    2                 2 ⎟
# ⎪ 2    2⎜-m_S - ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎟
# ⎪π ⋅log ⎜──────────────────────────────────⎟
# ⎪       ⎜          ________________________⎟
# ⎪       ⎜         ╱    2                 2 ⎟
# ⎪       ⎝-m_S + ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎠
# ⎪───────────────────────────────────────────         otherwise
# ⎩                     4
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mCH**2)/(mS**2))))/(1-np.sqrt(1-((4*mCH**2)/(mS**2)))))*(-sp.I*np.pi))**2;#######MODIFICADO#########
# array([0.09283761341094673, 0.09462138662287439, 0.09642380980419445,
#        0.09824495046738933, 0.10008487708040625, 0.10194365907824048,
#        0.10382136687475073, 0.10571807187471097, 0.1076338464861039,
#        0.10956876413266105], dtype=object)

# %%
FH(mCH,mS).simplify()
FH(200.0,np.linspace(120,130,10))
# Out:
# ⎧                        2 ⎛   2                 2     2⎛     m_S      ⎞⎞
# ⎪          4⋅m_{H__{\pm}} ⋅⎜m_S  - 4⋅m_{H__{\pm}} ⋅asin ⎜──────────────⎟⎟
# ⎪                          ⎝                            ⎝2⋅m_{H__{\pm}}⎠⎠
# ⎪          ──────────────────────────────────────────────────────────────
# ⎪                                          4
# ⎪                                       m_S
# ⎪
# ⎪                ⎛                            ⎛          _____________________
# ⎨                ⎜                            ⎜         ╱    2
# ⎪              2 ⎜   2    2             2    2⎜-m_S - ╲╱  m_S  - 4⋅m_{H__{\pm}
# ⎪4⋅m_{H__{\pm}} ⋅⎜m_S  - π ⋅m_{H__{\pm}} ⋅log ⎜───────────────────────────────
# ⎪                ⎜                            ⎜          _____________________
# ⎪                ⎜                            ⎜         ╱    2
# ⎪                ⎝                            ⎝-m_S + ╲╱  m_S  - 4⋅m_{H__{\pm}
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                          4
# ⎩                                       m_S
#
#
#                     2
#                  m_S
#        for ─────────────── ≤ 1
#                          2
#            4⋅m_{H__{\pm}}
#
# ___⎞⎞
#  2 ⎟⎟
# }  ⎟⎟
# ───⎟⎟
# ___⎟⎟
#  2 ⎟⎟
# }  ⎠⎠
# ─────         otherwise
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mCH**2)/(mS**2))))/(1-np.sqrt(1-((4*mCH**2)/(mS**2)))))*(-sp.I*np.pi))**2;#######MODIFICADO#########
# array([-0.3503226433267577, -0.350658784366409, -0.3509988203047514,
#        -0.3513427762704764, -0.35169067778636337, -0.35204255077504465,
#        -0.3523984215649774, -0.35275831689649856, -0.3531222639280247,
#        -0.35349029024236817], dtype=object)

# %%
gCH = sp.symbols(r'g_{H^{\pm}}',real=True)
AHc(gCH,mCH,mS).simplify()
AHc(0.3,200.0,np.linspace(120,130,10))
# Out:
# ⎧                             ⎛   2                 2     2⎛     m_S      ⎞⎞
# ⎪          4⋅g_{H__{\pm}}⋅m_W⋅⎜m_S  - 4⋅m_{H__{\pm}} ⋅asin ⎜──────────────⎟⎟
# ⎪                             ⎝                            ⎝2⋅m_{H__{\pm}}⎠⎠
# ⎪          ─────────────────────────────────────────────────────────────────
# ⎪                                            4
# ⎪                                         m_S
# ⎪
# ⎪                   ⎛                            ⎛          __________________
# ⎨                   ⎜                            ⎜         ╱    2
# ⎪                   ⎜   2    2             2    2⎜-m_S - ╲╱  m_S  - 4⋅m_{H__{\
# ⎪4⋅g_{H__{\pm}}⋅m_W⋅⎜m_S  - π ⋅m_{H__{\pm}} ⋅log ⎜────────────────────────────
# ⎪                   ⎜                            ⎜          __________________
# ⎪                   ⎜                            ⎜         ╱    2
# ⎪                   ⎝                            ⎝-m_S + ╲╱  m_S  - 4⋅m_{H__{\
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                            4
# ⎩                                         m_S
#
#
#                        2
#                     m_S
#           for ─────────────── ≤ 1
#                             2
#               4⋅m_{H__{\pm}}
#
# ______⎞⎞
#     2 ⎟⎟
# pm}}  ⎟⎟
# ──────⎟⎟
# ______⎟⎟
#     2 ⎟⎟
# pm}}  ⎠⎠
# ────────         otherwise
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mCH**2)/(mS**2))))/(1-np.sqrt(1-((4*mCH**2)/(mS**2)))))*(-sp.I*np.pi))**2;#######MODIFICADO#########
# array([-0.00021118937810971097, -0.00021139201821440695,
#        -0.0002115970063295671, -0.00021180435760383468,
#        -0.0002120140874234258, -0.0002122262114156049,
#        -0.00021244074545228493, -0.00021265770565367747,
#        -0.00021287710839203026, -0.00021309897029543487], dtype=object)

# %%
Ahgaga(ghtt,ghbb,ghWW,gCH,mCH,mS).simplify()
Ahgaga(0.1,0.2,0.4,0.3,200.0,np.linspace(120,130,10))
# Out:
#                    ⎛                    ⎛⎧
#                    ⎜                    ⎜⎪               2⎛     m_S      ⎞
#                    ⎜                    ⎜⎪           asin ⎜──────────────⎟
#                    ⎜                    ⎜⎪                ⎝2⋅m_{H__{\pm}}⎠
#                    ⎜                    ⎜⎪
#                    ⎜                    ⎜⎪
#                    ⎜                    ⎜⎪       ⎛ ⎛      ____________________
#                    ⎜                    ⎜⎪       ⎜ ⎜     ╱                   2
#                    ⎜                    ⎜⎪       ⎜ ⎜    ╱      4⋅m_{H__{\pm}}
#                    ⎜                  2 ⎜⎪       ⎜-⎜   ╱   1 - ───────────────
#                    ⎜    4⋅m_{H__{\pm}} ⋅⎜⎨       ⎜ ⎜  ╱                 2
#                    ⎜                    ⎜⎪ 2    2⎜ ⎝╲╱               m_S
#                    ⎜                    ⎜⎪π ⋅log ⎜────────────────────────────
#                    ⎜                    ⎜⎪       ⎜        ____________________
#                    ⎜                    ⎜⎪       ⎜       ╱                   2
#                    ⎜                    ⎜⎪       ⎜      ╱      4⋅m_{H__{\pm}}
#                    ⎜                    ⎜⎪       ⎜     ╱   1 - ───────────────
#                    ⎜                    ⎜⎪       ⎜    ╱                 2
#                    ⎜                    ⎜⎪       ⎝  ╲╱               m_S
#                    ⎜                    ⎜⎪────────────────────────────────────
#                    ⎜                    ⎝⎩                     4
# 4⋅g_{H__{\pm}}⋅m_W⋅⎜1 - ──────────────────────────────────────────────────────
#                    ⎜                                                 2
#                    ⎝                                              m_S
# ──────────────────────────────────────────────────────────────────────────────
#                                                           2
#                                                        m_S
#
#                        2         ⎞⎞           ⎛                         ⎛⎧
#                     m_S          ⎟⎟           ⎜                         ⎜⎪
#           for ─────────────── ≤ 1⎟⎟           ⎜                         ⎜⎪
#                             2    ⎟⎟           ⎜                         ⎜⎪
#               4⋅m_{H__{\pm}}     ⎟⎟           ⎜                         ⎜⎪
#                                  ⎟⎟           ⎜                         ⎜⎪
# _    ⎞ ⎞                         ⎟⎟           ⎜                         ⎜⎪
#      ⎟ ⎟                         ⎟⎟           ⎜                         ⎜⎪
#      ⎟ ⎟                         ⎟⎟           ⎜            ⎛         2⎞ ⎜⎪
#   + 1⎟ ⎟                         ⎟⎟           ⎜          2 ⎜    4⋅m_W ⎟ ⎜⎪
#      ⎟ ⎟                         ⎟⎟           ⎜    12⋅m_W ⋅⎜2 - ──────⎟⋅⎜⎨
#      ⎠ ⎟                         ⎟⎟           ⎜            ⎜        2 ⎟ ⎜⎪ 2
# ───────⎟                         ⎟⎟           ⎜            ⎝     m_S  ⎠ ⎜⎪π ⋅l
# _      ⎟                         ⎟⎟           ⎜                         ⎜⎪
#        ⎟                         ⎟⎟           ⎜                         ⎜⎪
#        ⎟                         ⎟⎟           ⎜                         ⎜⎪
#   - 1  ⎟                         ⎟⎟           ⎜                         ⎜⎪
#        ⎟                         ⎟⎟           ⎜                         ⎜⎪
#        ⎠                         ⎟⎟           ⎜                         ⎜⎪
# ────────         otherwise       ⎟⎟           ⎜                         ⎜⎪────
#                                  ⎠⎟           ⎜                         ⎝⎩
# ──────────────────────────────────⎟   g_{hWW}⋅⎜2 + ───────────────────────────
#                                   ⎟           ⎜
#                                   ⎠           ⎝
# ─────────────────────────────────── + ────────────────────────────────────────
#
#
#
#                                          2     ⎞          ⎞
#            2⎛ m_S ⎞                   m_S      ⎟          ⎟
#        asin ⎜─────⎟              for ────── ≤ 1⎟          ⎟
#             ⎝2⋅m_W⎠                       2    ⎟          ⎟
#                                      4⋅m_W     ⎟          ⎟
#                                                ⎟          ⎟
#    ⎛ ⎛      ____________    ⎞ ⎞                ⎟          ⎟
#    ⎜ ⎜     ╱          2     ⎟ ⎟                ⎟          ⎟
#    ⎜ ⎜    ╱      4⋅m_W      ⎟ ⎟                ⎟          ⎟
#    ⎜-⎜   ╱   1 - ──────  + 1⎟ ⎟                ⎟          ⎟
#    ⎜ ⎜  ╱            2      ⎟ ⎟                ⎟          ⎟
#   2⎜ ⎝╲╱          m_S       ⎠ ⎟                ⎟          ⎟
# og ⎜──────────────────────────⎟                ⎟          ⎟             2
#    ⎜        ____________      ⎟                ⎟          ⎟   16⋅g_{hbb} ⋅m_W⋅
#    ⎜       ╱          2       ⎟                ⎟          ⎟
#    ⎜      ╱      4⋅m_W        ⎟                ⎟          ⎟
#    ⎜     ╱   1 - ──────  - 1  ⎟                ⎟          ⎟
#    ⎜    ╱            2        ⎟                ⎟          ⎟
#    ⎝  ╲╱          m_S         ⎠                ⎟          ⎟
# ───────────────────────────────    otherwise   ⎟         2⎟
#              4                                 ⎠   12⋅m_W ⎟
# ──────────────────────────────────────────────── + ───────⎟
#             2                                           2 ⎟
#          m_S                                         m_S  ⎠
# ─────────────────────────────────────────────────────────── - ────────────────
#         m_W
#
#
#
#
#
#     ⎛             ⎛⎧                                         2     ⎞    ⎞
#     ⎜             ⎜⎪             2⎛ m_S ⎞                 m_S      ⎟    ⎟
#     ⎜             ⎜⎪         asin ⎜─────⎟            for ────── ≤ 1⎟    ⎟
#     ⎜             ⎜⎪              ⎝2⋅m_b⎠                     2    ⎟    ⎟
#     ⎜             ⎜⎪                                     4⋅m_b     ⎟    ⎟
#     ⎜             ⎜⎪                                               ⎟    ⎟
#     ⎜             ⎜⎪       ⎛      ____________    ⎞                ⎟    ⎟
#     ⎜             ⎜⎪       ⎜     ╱          2     ⎟                ⎟    ⎟
#     ⎜⎛         2⎞ ⎜⎪ 2    2⎜    ╱      4⋅m_b      ⎟                ⎟    ⎟
#     ⎜⎜    4⋅m_b ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ──────  + 1⎟                ⎟    ⎟
# m_b⋅⎜⎜1 - ──────⎟⋅⎜⎨       ⎜  ╱            2      ⎟                ⎟ + 1⎟   64
#     ⎜⎜        2 ⎟ ⎜⎪       ⎝╲╱          m_S       ⎠                ⎟    ⎟
#     ⎜⎝     m_S  ⎠ ⎜⎪───────────────────────────────    otherwise   ⎟    ⎟
#     ⎜             ⎜⎪                            2                  ⎟    ⎟
#     ⎜             ⎜⎪    ⎛      ____________    ⎞                   ⎟    ⎟
#     ⎜             ⎜⎪    ⎜     ╱          2     ⎟                   ⎟    ⎟
#     ⎜             ⎜⎪    ⎜    ╱      4⋅m_b      ⎟                   ⎟    ⎟
#     ⎜             ⎜⎪  4⋅⎜   ╱   1 - ──────  - 1⎟                   ⎟    ⎟
#     ⎜             ⎜⎪    ⎜  ╱            2      ⎟                   ⎟    ⎟
#     ⎜             ⎜⎪    ⎝╲╱          m_S       ⎠                   ⎟    ⎟
#     ⎝             ⎝⎩                                               ⎠    ⎠
# ───────────────────────────────────────────────────────────────────────── - ──
#                                2
#                           3⋅m_S
#
#
#
#
#                  ⎛            ⎛⎧                                        2    ⎞
#                  ⎜            ⎜⎪             2⎛m_S ⎞                 m_S     ⎟
#                  ⎜            ⎜⎪         asin ⎜────⎟            for ───── ≤ 1⎟
#                  ⎜            ⎜⎪              ⎝2⋅mₜ⎠                    2    ⎟
#                  ⎜            ⎜⎪                                    4⋅mₜ     ⎟
#                  ⎜            ⎜⎪                                             ⎟
#                  ⎜            ⎜⎪       ⎛      ___________    ⎞               ⎟
#                  ⎜            ⎜⎪       ⎜     ╱         2     ⎟               ⎟
#                  ⎜⎛        2⎞ ⎜⎪ 2    2⎜    ╱      4⋅mₜ      ⎟               ⎟
#         2        ⎜⎜    4⋅mₜ ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ─────  + 1⎟               ⎟
# ⋅g_{htt} ⋅m_W⋅mₜ⋅⎜⎜1 - ─────⎟⋅⎜⎨       ⎜  ╱            2     ⎟               ⎟
#                  ⎜⎜        2⎟ ⎜⎪       ⎝╲╱          m_S      ⎠               ⎟
#                  ⎜⎝     m_S ⎠ ⎜⎪──────────────────────────────    otherwise  ⎟
#                  ⎜            ⎜⎪                           2                 ⎟
#                  ⎜            ⎜⎪    ⎛      ___________    ⎞                  ⎟
#                  ⎜            ⎜⎪    ⎜     ╱         2     ⎟                  ⎟
#                  ⎜            ⎜⎪    ⎜    ╱      4⋅mₜ      ⎟                  ⎟
#                  ⎜            ⎜⎪  4⋅⎜   ╱   1 - ─────  - 1⎟                  ⎟
#                  ⎜            ⎜⎪    ⎜  ╱            2     ⎟                  ⎟
#                  ⎜            ⎜⎪    ⎝╲╱          m_S      ⎠                  ⎟
#                  ⎝            ⎝⎩                                             ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                            2
#                                       3⋅m_S
#
#
#
#
#     ⎞
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#  + 1⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎟
#     ⎠
# ─────
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(-sp.I*np.pi))**2;#MODIFICADO#
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:160: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mWp**2)/(mS**2))))/(1-np.sqrt(1-((4*mWp**2)/(mS**2)))))*(-sp.I*np.pi))**2; #######MODIFICADO#########
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mCH**2)/(mS**2))))/(1-np.sqrt(1-((4*mCH**2)/(mS**2)))))*(-sp.I*np.pi))**2;#######MODIFICADO#########
# array([-991.206580037290, -1009.84711424911, -1028.65947208312,
#        -1047.64365262846, -1066.79965498437, -1086.12747825639,
#        -1105.62712155244, -1125.29858397864, -1145.14186463454,
#        -1165.15696260824], dtype=object)

# %%
WidthHgaga(ghtt,ghbb,ghWW,gCH,mCH,mS)#.simplify()
WidthHgaga(0.1,0.2,0.4,0.3,200.0,np.linspace(120,130,10))
# Out:
#
#                  │                   ⎛                    ⎛⎧
#                  │                   ⎜                    ⎜⎪             2⎛
#                  │                   ⎜                    ⎜⎪         asin ⎜───
#                  │                   ⎜                    ⎜⎪              ⎝2⋅m
#                  │                   ⎜                    ⎜⎪
#                  │                   ⎜                    ⎜⎪
#                  │                   ⎜                    ⎜⎪       ⎛      ____
#                  │                   ⎜                    ⎜⎪       ⎜     ╱
#                  │                   ⎜                    ⎜⎪       ⎜    ╱
#                  │                   ⎜                  2 ⎜⎪       ⎜   ╱   1 -
#                  │                   ⎜    4⋅m_{H__{\pm}} ⋅⎜⎨       ⎜  ╱
#                  │                   ⎜                    ⎜⎪ 2    2⎜╲╱
#                  │                   ⎜                    ⎜⎪π ⋅log ⎜──────────
#                  │                   ⎜                    ⎜⎪       ⎜
#                  │                   ⎜                    ⎜⎪       ⎜         ╱
#                  │                   ⎜                    ⎜⎪       ⎜        ╱
#                  │                   ⎜                    ⎜⎪       ⎜1 -    ╱
#                  │                   ⎜                    ⎜⎪       ⎜      ╱
#                  │                   ⎜                    ⎜⎪       ⎝    ╲╱
#                  │                   ⎜                    ⎜⎪──────────────────
#                  │                   ⎜                    ⎝⎩
#                  │4⋅g_{H__{\pm}}⋅m_W⋅⎜1 - ────────────────────────────────────
#                  │                   ⎜
#           2    3 │                   ⎝
# \alpha_{e} ⋅m_S ⋅│────────────────────────────────────────────────────────────
#                  │                                                        2
#                  │                                                     m_S
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                      2         ⎞⎞           ⎛
#   m_S      ⎞                      m_S          ⎟⎟           ⎜
# ───────────⎟            for ─────────────── ≤ 1⎟⎟           ⎜
# _{H__{\pm}}⎠                              2    ⎟⎟           ⎜
#                             4⋅m_{H__{\pm}}     ⎟⎟           ⎜
#                                                ⎟⎟           ⎜
# _________________    ⎞                         ⎟⎟           ⎜
#                2     ⎟                         ⎟⎟           ⎜
#  4⋅m_{H__{\pm}}      ⎟                         ⎟⎟           ⎜            ⎛
#  ───────────────  + 1⎟                         ⎟⎟           ⎜          2 ⎜
#           2          ⎟                         ⎟⎟           ⎜    12⋅m_W ⋅⎜2 -
#        m_S           ⎟                         ⎟⎟           ⎜            ⎜
# ─────────────────────⎟                         ⎟⎟           ⎜            ⎝
# _____________________⎟                         ⎟⎟           ⎜
#                    2 ⎟                         ⎟⎟           ⎜
#      4⋅m_{H__{\pm}}  ⎟                         ⎟⎟           ⎜
#  1 - ─────────────── ⎟                         ⎟⎟           ⎜
#               2      ⎟                         ⎟⎟           ⎜
#            m_S       ⎠                         ⎟⎟           ⎜
# ──────────────────────         otherwise       ⎟⎟           ⎜
#  4                                             ⎠⎟           ⎜
# ────────────────────────────────────────────────⎟   g_{hWW}⋅⎜2 + ─────────────
#        2                                        ⎟           ⎜
#     m_S                                         ⎠           ⎝
# ───────────────────────────────────────────────── + ──────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#         ⎛⎧                                         2     ⎞          ⎞
#         ⎜⎪             2⎛ m_S ⎞                 m_S      ⎟          ⎟
#         ⎜⎪         asin ⎜─────⎟            for ────── ≤ 1⎟          ⎟
#         ⎜⎪              ⎝2⋅m_W⎠                     2    ⎟          ⎟
#         ⎜⎪                                     4⋅m_W     ⎟          ⎟
#         ⎜⎪                                               ⎟          ⎟
#         ⎜⎪       ⎛      ____________    ⎞                ⎟          ⎟
#         ⎜⎪       ⎜     ╱          2     ⎟                ⎟          ⎟
#      2⎞ ⎜⎪       ⎜    ╱      4⋅m_W      ⎟                ⎟          ⎟
# 4⋅m_W ⎟ ⎜⎪       ⎜   ╱   1 - ──────  + 1⎟                ⎟          ⎟
# ──────⎟⋅⎜⎨       ⎜  ╱            2      ⎟                ⎟          ⎟
#     2 ⎟ ⎜⎪ 2    2⎜╲╱          m_S       ⎟                ⎟          ⎟
#  m_S  ⎠ ⎜⎪π ⋅log ⎜──────────────────────⎟                ⎟          ⎟
#         ⎜⎪       ⎜          ____________⎟                ⎟          ⎟   16⋅g_{
#         ⎜⎪       ⎜         ╱          2 ⎟                ⎟          ⎟
#         ⎜⎪       ⎜        ╱      4⋅m_W  ⎟                ⎟          ⎟
#         ⎜⎪       ⎜1 -    ╱   1 - ────── ⎟                ⎟          ⎟
#         ⎜⎪       ⎜      ╱            2  ⎟                ⎟          ⎟
#         ⎜⎪       ⎝    ╲╱          m_S   ⎠                ⎟          ⎟
#         ⎜⎪───────────────────────────────    otherwise   ⎟         2⎟
#         ⎝⎩               4                               ⎠   12⋅m_W ⎟
# ────────────────────────────────────────────────────────── + ───────⎟
#                         2                                         2 ⎟
#                      m_S                                       m_S  ⎠
# ───────────────────────────────────────────────────────────────────── - ──────
#                     m_W
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                 3    2
#                                           1024⋅π ⋅m_W
#
#
#
#
#
#               ⎛             ⎛⎧                                         2     ⎞
#               ⎜             ⎜⎪             2⎛ m_S ⎞                 m_S      ⎟
#               ⎜             ⎜⎪         asin ⎜─────⎟            for ────── ≤ 1⎟
#               ⎜             ⎜⎪              ⎝2⋅m_b⎠                     2    ⎟
#               ⎜             ⎜⎪                                     4⋅m_b     ⎟
#               ⎜             ⎜⎪                                               ⎟
#               ⎜             ⎜⎪       ⎛      ____________    ⎞                ⎟
#               ⎜             ⎜⎪       ⎜     ╱          2     ⎟                ⎟
#               ⎜⎛         2⎞ ⎜⎪ 2    2⎜    ╱      4⋅m_b      ⎟                ⎟
#     2         ⎜⎜    4⋅m_b ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ──────  + 1⎟                ⎟
# hbb} ⋅m_W⋅m_b⋅⎜⎜1 - ──────⎟⋅⎜⎨       ⎜  ╱            2      ⎟                ⎟
#               ⎜⎜        2 ⎟ ⎜⎪       ⎝╲╱          m_S       ⎠                ⎟
#               ⎜⎝     m_S  ⎠ ⎜⎪───────────────────────────────    otherwise   ⎟
#               ⎜             ⎜⎪                            2                  ⎟
#               ⎜             ⎜⎪    ⎛          ____________⎞                   ⎟
#               ⎜             ⎜⎪    ⎜         ╱          2 ⎟                   ⎟
#               ⎜             ⎜⎪    ⎜        ╱      4⋅m_b  ⎟                   ⎟
#               ⎜             ⎜⎪  4⋅⎜1 -    ╱   1 - ────── ⎟                   ⎟
#               ⎜             ⎜⎪    ⎜      ╱            2  ⎟                   ⎟
#               ⎜             ⎜⎪    ⎝    ╲╱          m_S   ⎠                   ⎟
#               ⎝             ⎝⎩                                               ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                          2
#                                     3⋅m_S
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#     ⎞                      ⎛            ⎛⎧
#     ⎟                      ⎜            ⎜⎪             2⎛m_S ⎞
#     ⎟                      ⎜            ⎜⎪         asin ⎜────⎟            for
#     ⎟                      ⎜            ⎜⎪              ⎝2⋅mₜ⎠
#     ⎟                      ⎜            ⎜⎪
#     ⎟                      ⎜            ⎜⎪
#     ⎟                      ⎜            ⎜⎪       ⎛      ___________    ⎞
#     ⎟                      ⎜            ⎜⎪       ⎜     ╱         2     ⎟
#     ⎟                      ⎜⎛        2⎞ ⎜⎪ 2    2⎜    ╱      4⋅mₜ      ⎟
#     ⎟             2        ⎜⎜    4⋅mₜ ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ─────  + 1⎟
#  + 1⎟   64⋅g_{htt} ⋅m_W⋅mₜ⋅⎜⎜1 - ─────⎟⋅⎜⎨       ⎜  ╱            2     ⎟
#     ⎟                      ⎜⎜        2⎟ ⎜⎪       ⎝╲╱          m_S      ⎠
#     ⎟                      ⎜⎝     m_S ⎠ ⎜⎪──────────────────────────────    ot
#     ⎟                      ⎜            ⎜⎪                           2
#     ⎟                      ⎜            ⎜⎪    ⎛          ___________⎞
#     ⎟                      ⎜            ⎜⎪    ⎜         ╱         2 ⎟
#     ⎟                      ⎜            ⎜⎪    ⎜        ╱      4⋅mₜ  ⎟
#     ⎟                      ⎜            ⎜⎪  4⋅⎜1 -    ╱   1 - ───── ⎟
#     ⎟                      ⎜            ⎜⎪    ⎜      ╱            2 ⎟
#     ⎟                      ⎜            ⎜⎪    ⎝    ╲╱          m_S  ⎠
#     ⎠                      ⎝            ⎝⎩
# ───── - ──────────────────────────────────────────────────────────────────────
#                                                      2
#                                                 3⋅m_S
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 2
#                │
#                │
#                │
#     2    ⎞    ⎞│
#  m_S     ⎟    ⎟│
# ───── ≤ 1⎟    ⎟│
#     2    ⎟    ⎟│
# 4⋅mₜ     ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟ + 1⎟│
#          ⎟    ⎟│
# herwise  ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟    ⎟│
#          ⎟    ⎟│
#          ⎠    ⎠│
# ───────────────│
#                │
#                │
# ─────────────────
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(-sp.I*np.pi))**2;#MODIFICADO#
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:160: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mWp**2)/(mS**2))))/(1-np.sqrt(1-((4*mWp**2)/(mS**2)))))*(-sp.I*np.pi))**2; #######MODIFICADO#########
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mCH**2)/(mS**2))))/(1-np.sqrt(1-((4*mCH**2)/(mS**2)))))*(-sp.I*np.pi))**2;#######MODIFICADO#########
# array([0.440725295442656, 0.470282815593262, 0.501521635137180,
#        0.534520624086741, 0.569361581880237, 0.606129318150255,
#        0.644911734960336, 0.685799910522858, 0.728888184410918,
#        0.774274244277346], dtype=object)

# %%
RTW(mS)#.simplify()
RTW(np.linspace(120,130,10))
# Out:
#
#
#
#        ⎛       2⎞ ⎛          2         4⎞
#      2 ⎜    m_W ⎟ ⎜    13⋅m_W    47⋅m_W ⎟
#   m_S ⋅⎜1 - ────⎟⋅⎜2 - ─────── + ───────⎟
#        ⎜       2⎟ ⎜         2         4 ⎟   ⎛         2        4⎞    ⎛   2⎞
#        ⎝    m_S ⎠ ⎝      m_S       m_S  ⎠   ⎜3   9⋅m_W    6⋅m_W ⎟    ⎜m_W ⎟
# - ─────────────────────────────────────── - ⎜─ - ────── + ──────⎟⋅log⎜────⎟ +
#                         2                   ⎜2       2        4 ⎟    ⎜   2⎟
#                    2⋅m_W                    ⎝     m_S      m_S  ⎠    ⎝m_S ⎠
#
#
#
#
#
#
#                             ⎛     ⎛          2⎞⎞
#                             ⎜   3 ⎜     3⋅m_W ⎟⎟
#                             ⎜m_S ⋅⎜-1 + ──────⎟⎟
# ⎛          2         4⎞     ⎜     ⎜         2 ⎟⎟
# ⎜    24⋅m_W    60⋅m_W ⎟     ⎜     ⎝      m_S  ⎠⎟
# ⎜3 - ─────── + ───────⎟⋅acos⎜──────────────────⎟
# ⎜         2         4 ⎟     ⎜           3      ⎟
# ⎝      m_S       m_S  ⎠     ⎝      2⋅m_W       ⎠
# ────────────────────────────────────────────────
#                       ___________
#                      ╱     2
#                     ╱   m_W
#                    ╱    ────
#                   ╱        2
#                  ╱      m_S
#                ╲╱      4     - 1
# array([-0.08142428, -0.10491518, -0.12832073, -0.15151597, -0.17437759,
#        -0.19678384, -0.21861431, -0.2397497 , -0.26007151, -0.27946176])

# %%
RTZ(mS)#.simplify()
RTZ(np.linspace(120,130,10))
# Out:
#
#
#
#        ⎛       2⎞ ⎛          2         4⎞
#      2 ⎜    m_Z ⎟ ⎜    13⋅m_Z    47⋅m_Z ⎟
#   m_S ⋅⎜1 - ────⎟⋅⎜2 - ─────── + ───────⎟
#        ⎜       2⎟ ⎜         2         4 ⎟   ⎛         2        4⎞    ⎛   2⎞
#        ⎝    m_S ⎠ ⎝      m_S       m_S  ⎠   ⎜3   9⋅m_Z    6⋅m_Z ⎟    ⎜m_Z ⎟
# - ─────────────────────────────────────── - ⎜─ - ────── + ──────⎟⋅log⎜────⎟ +
#                         2                   ⎜2       2        4 ⎟    ⎜   2⎟
#                    2⋅m_Z                    ⎝     m_S      m_S  ⎠    ⎝m_S ⎠
#
#
#
#
#
#
#                             ⎛     ⎛          2⎞⎞
#                             ⎜   3 ⎜     3⋅m_Z ⎟⎟
#                             ⎜m_S ⋅⎜-1 + ──────⎟⎟
# ⎛          2         4⎞     ⎜     ⎜         2 ⎟⎟
# ⎜    24⋅m_Z    60⋅m_Z ⎟     ⎜     ⎝      m_S  ⎠⎟
# ⎜3 - ─────── + ───────⎟⋅acos⎜──────────────────⎟
# ⎜         2         4 ⎟     ⎜           3      ⎟
# ⎝      m_S       m_S  ⎠     ⎝      2⋅m_Z       ⎠
# ────────────────────────────────────────────────
#                       ___________
#                      ╱     2
#                     ╱   m_Z
#                    ╱    ────
#                   ╱        2
#                  ╱      m_S
#                ╲╱      4     - 1
# array([0.16964468, 0.15835025, 0.14578711, 0.1320438 , 0.11721097,
#        0.10138073, 0.08464612, 0.0671007 , 0.04883813, 0.02995186])

# %%
δZ
# Out:
# 304.6635823627211

# %%
WidthHWW(ghWW,mS)#.simplify()
WidthHWW(0.3,np.linspace(120,130,10))
# Out:
#              ⎛
#              ⎜
#              ⎜
#              ⎜       ⎛       2⎞ ⎛          2         4⎞
#              ⎜     2 ⎜    m_W ⎟ ⎜    13⋅m_W    47⋅m_W ⎟
#              ⎜  m_S ⋅⎜1 - ────⎟⋅⎜2 - ─────── + ───────⎟
#              ⎜       ⎜       2⎟ ⎜         2         4 ⎟   ⎛         2        4
#        2     ⎜       ⎝    m_S ⎠ ⎝      m_S       m_S  ⎠   ⎜3   9⋅m_W    6⋅m_W
# g_{hWW} ⋅m_S⋅⎜- ─────────────────────────────────────── - ⎜─ - ────── + ──────
#              ⎜                        2                   ⎜2       2        4
#              ⎜                   2⋅m_W                    ⎝     m_S      m_S
#              ⎜
#              ⎜
#              ⎜
#              ⎜
#              ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                       3    4
#                                                                  512⋅π ⋅m_W
#
#                                           ⎛     ⎛          2⎞⎞⎞
#                                           ⎜   3 ⎜     3⋅m_W ⎟⎟⎟
#                                           ⎜m_S ⋅⎜-1 + ──────⎟⎟⎟
#               ⎛          2         4⎞     ⎜     ⎜         2 ⎟⎟⎟
#               ⎜    24⋅m_W    60⋅m_W ⎟     ⎜     ⎝      m_S  ⎠⎟⎟
#               ⎜3 - ─────── + ───────⎟⋅acos⎜──────────────────⎟⎟
# ⎞    ⎛   2⎞   ⎜         2         4 ⎟     ⎜           3      ⎟⎟
# ⎟    ⎜m_W ⎟   ⎝      m_S       m_S  ⎠     ⎝      2⋅m_W       ⎠⎟
# ⎟⋅log⎜────⎟ + ────────────────────────────────────────────────⎟
# ⎟    ⎜   2⎟                         ___________               ⎟
# ⎠    ⎝m_S ⎠                        ╱     2                    ⎟
#                                   ╱   m_W                     ⎟
#                                  ╱    ────                    ⎟
#                                 ╱        2                    ⎟
#                                ╱      m_S                     ⎟
#                              ╲╱      4     - 1                ⎠
# ───────────────────────────────────────────────────────────────
# array([-1.32705137e-12, -1.72573800e-12, -2.13009780e-12, -2.53799879e-12,
#        -2.94726186e-12, -3.35565969e-12, -3.76091459e-12, -4.16069548e-12,
#        -4.55261364e-12, -4.93421735e-12])

# %%
ghZZ = sp.symbols('g_{HZZ}',real=True)
WidthHZZ(ghZZ,mS)#.simplify()
WidthHZZ(0.3,np.linspace(120,130,10))
# Out:
#                       ⎛
#                       ⎜
#                       ⎜
#                       ⎜       ⎛       2⎞ ⎛          2         4⎞
#                       ⎜     2 ⎜    m_Z ⎟ ⎜    13⋅m_Z    47⋅m_Z ⎟
#                       ⎜  m_S ⋅⎜1 - ────⎟⋅⎜2 - ─────── + ───────⎟
#                       ⎜       ⎜       2⎟ ⎜         2         4 ⎟   ⎛         2
#                 2     ⎜       ⎝    m_S ⎠ ⎝      m_S       m_S  ⎠   ⎜3   9⋅m_Z
# \delta_Z⋅g_{HZZ} ⋅m_S⋅⎜- ─────────────────────────────────────── - ⎜─ - ──────
#                       ⎜                        2                   ⎜2       2
#                       ⎜                   2⋅m_Z                    ⎝     m_S
#                       ⎜
#                       ⎜
#                       ⎜
#                       ⎜
#                       ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                            3
#                                                                      2048⋅π ⋅m
#
#                                                    ⎛     ⎛          2⎞⎞⎞
#                                                    ⎜   3 ⎜     3⋅m_Z ⎟⎟⎟
#                                                    ⎜m_S ⋅⎜-1 + ──────⎟⎟⎟
#                        ⎛          2         4⎞     ⎜     ⎜         2 ⎟⎟⎟
#                        ⎜    24⋅m_Z    60⋅m_Z ⎟     ⎜     ⎝      m_S  ⎠⎟⎟
#                        ⎜3 - ─────── + ───────⎟⋅acos⎜──────────────────⎟⎟
#         4⎞    ⎛   2⎞   ⎜         2         4 ⎟     ⎜           3      ⎟⎟
#    6⋅m_Z ⎟    ⎜m_Z ⎟   ⎝      m_S       m_S  ⎠     ⎝      2⋅m_Z       ⎠⎟
#  + ──────⎟⋅log⎜────⎟ + ────────────────────────────────────────────────⎟
#        4 ⎟    ⎜   2⎟                         ___________               ⎟
#     m_S  ⎠    ⎝m_S ⎠                        ╱     2                    ⎟
#                                            ╱   m_Z                     ⎟
#                                           ╱    ────                    ⎟
#                                          ╱        2                    ⎟
#                                         ╱      m_S                     ⎟
#                                       ╲╱      4     - 1                ⎠
# ────────────────────────────────────────────────────────────────────────
#   4
# _Z
# array([1.27134038e-10, 1.19768630e-10, 1.11278082e-10, 1.01704184e-10,
#        9.10928136e-11, 7.94935121e-11, 6.69591241e-11, 5.35454709e-11,
#        3.93110650e-11, 2.43168621e-11])

# %%
BRhfifj(ghtt,3,mb['symbol'],mb['symbol'])
BRhfifj(0.1,3.0,mb['value'],mb['value'])
# Out:
#                                             3/2
#                              ⎛        2    ⎞
#                         2    ⎜  16⋅m_b     ⎟
# 11.4329268292683⋅g_{htt} ⋅mₕ⋅⎜- ─────── + 4⎟
#                              ⎜      2      ⎟
#                              ⎝    mₕ       ⎠
# ───────────────────────────────────────────────
#                        π
# 36.20099475928305

# %%
BRhgaga(ghtt,ghbb,ghWW,gCH,mCH)
BRhgaga(0.1,0.2,0.3,0.11,np.linspace(200,300,10))
# Out:
#
#                                   │                   ⎛                    ⎛⎧
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                  2 ⎜⎪
#                                   │                   ⎜    4⋅m_{H__{\pm}} ⋅⎜⎨
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪π
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪─
#                                   │                   ⎜                    ⎝⎩
#                                   │4⋅g_{H__{\pm}}⋅m_W⋅⎜1 - ───────────────────
#                                   │                   ⎜
#                             2   3 │                   ⎝
# 0.238185975609756⋅\alpha_{e} ⋅mₕ ⋅│───────────────────────────────────────────
#                                   │
#                                   │
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                      2          ⎞⎞           ⎛
#             2⎛      mₕ      ⎞                      mₕ           ⎟⎟           ⎜
#         asin ⎜──────────────⎟            for ─────────────── ≤ 1⎟⎟           ⎜
#              ⎝2⋅m_{H__{\pm}}⎠                              2    ⎟⎟           ⎜
#                                              4⋅m_{H__{\pm}}     ⎟⎟           ⎜
#                                                                 ⎟⎟           ⎜
#       ⎛      _____________________    ⎞                         ⎟⎟           ⎜
#       ⎜     ╱                   2     ⎟                         ⎟⎟           ⎜
#       ⎜    ╱      4⋅m_{H__{\pm}}      ⎟                         ⎟⎟           ⎜
#       ⎜   ╱   1 - ───────────────  + 1⎟                         ⎟⎟           ⎜
#       ⎜  ╱                2           ⎟                         ⎟⎟           ⎜
# 2    2⎜╲╱               mₕ            ⎟                         ⎟⎟           ⎜
#  ⋅log ⎜───────────────────────────────⎟                         ⎟⎟           ⎜
#       ⎜          _____________________⎟                         ⎟⎟           ⎜
#       ⎜         ╱                   2 ⎟                         ⎟⎟           ⎜
#       ⎜        ╱      4⋅m_{H__{\pm}}  ⎟                         ⎟⎟           ⎜
#       ⎜1 -    ╱   1 - ─────────────── ⎟                         ⎟⎟           ⎜
#       ⎜      ╱                2       ⎟                         ⎟⎟           ⎜
#       ⎝    ╲╱               mₕ        ⎠                         ⎟⎟           ⎜
# ───────────────────────────────────────         otherwise       ⎟⎟           ⎜
#                   4                                             ⎠⎟           ⎜
# ─────────────────────────────────────────────────────────────────⎟   g_{hWW}⋅⎜
#                        2                                         ⎟           ⎜
#                      mₕ                                          ⎠           ⎝
# ────────────────────────────────────────────────────────────────── + ─────────
#             2
#           mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                        ⎛⎧                                          2      ⎞
#                        ⎜⎪              2⎛  mₕ ⎞                  mₕ       ⎟
#                        ⎜⎪          asin ⎜─────⎟             for ────── ≤ 1⎟
#                        ⎜⎪               ⎝2⋅m_W⎠                      2    ⎟
#                        ⎜⎪                                       4⋅m_W     ⎟
#                        ⎜⎪                                                 ⎟
#                        ⎜⎪       ⎛      ______________    ⎞                ⎟
#                        ⎜⎪       ⎜     ╱        2         ⎟                ⎟
#         ⎛       2    ⎞ ⎜⎪       ⎜    ╱    4⋅m_W          ⎟                ⎟
#       2 ⎜  4⋅m_W     ⎟ ⎜⎪       ⎜   ╱   - ────── + 1  + 1⎟                ⎟
# 12⋅m_W ⋅⎜- ────── + 2⎟⋅⎜⎨       ⎜  ╱         2           ⎟                ⎟
#         ⎜     2      ⎟ ⎜⎪ 2    2⎜╲╱        mₕ            ⎟                ⎟
#         ⎝   mₕ       ⎠ ⎜⎪π ⋅log ⎜────────────────────────⎟                ⎟
#                        ⎜⎪       ⎜          ______________⎟                ⎟
#                        ⎜⎪       ⎜         ╱        2     ⎟                ⎟
#                        ⎜⎪       ⎜        ╱    4⋅m_W      ⎟                ⎟
#                        ⎜⎪       ⎜1 -    ╱   - ────── + 1 ⎟                ⎟
#                        ⎜⎪       ⎜      ╱         2       ⎟                ⎟
#                        ⎜⎪       ⎝    ╲╱        mₕ        ⎠                ⎟
#                        ⎜⎪─────────────────────────────────    otherwise   ⎟
#                        ⎝⎩                4                                ⎠
# ─────────────────────────────────────────────────────────────────────────── +
#                                       2
#                                     mₕ
# ──────────────────────────────────────────────────────────────────────────────
#                                        m_W
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                          3    2
#                                                         π ⋅m_W
#
#
#            ⎞
#            ⎟
#            ⎟
#            ⎟                       ⎛               ⎛⎧
#            ⎟                       ⎜               ⎜⎪              2⎛  mₕ ⎞
#            ⎟                       ⎜               ⎜⎪          asin ⎜─────⎟
#            ⎟                       ⎜               ⎜⎪               ⎝2⋅m_b⎠
#            ⎟                       ⎜               ⎜⎪
#            ⎟                       ⎜               ⎜⎪
#            ⎟                       ⎜               ⎜⎪       ⎛      ___________
#            ⎟                       ⎜               ⎜⎪       ⎜     ╱        2
#            ⎟                       ⎜⎛       2    ⎞ ⎜⎪ 2    2⎜    ╱    4⋅m_b
#            ⎟             2         ⎜⎜  4⋅m_b     ⎟ ⎜⎪π ⋅log ⎜   ╱   - ────── +
#            ⎟   16⋅g_{hbb} ⋅m_W⋅m_b⋅⎜⎜- ────── + 1⎟⋅⎜⎨       ⎜  ╱         2
#            ⎟                       ⎜⎜     2      ⎟ ⎜⎪       ⎝╲╱        mₕ
#            ⎟                       ⎜⎝   mₕ       ⎠ ⎜⎪─────────────────────────
#            ⎟                       ⎜               ⎜⎪
#            ⎟                       ⎜               ⎜⎪    ⎛          __________
#            ⎟                       ⎜               ⎜⎪    ⎜         ╱        2
#       2    ⎟                       ⎜               ⎜⎪    ⎜        ╱    4⋅m_b
# 12⋅m_W     ⎟                       ⎜               ⎜⎪  4⋅⎜1 -    ╱   - ──────
# ─────── + 2⎟                       ⎜               ⎜⎪    ⎜      ╱         2
#     2      ⎟                       ⎜               ⎜⎪    ⎝    ╲╱        mₕ
#   mₕ       ⎠                       ⎝               ⎝⎩
# ──────────── - ───────────────────────────────────────────────────────────────
#                                                                2
#                                                            3⋅mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#                  2      ⎞    ⎞                      ⎛            ⎛⎧
#                mₕ       ⎟    ⎟                      ⎜            ⎜⎪
#           for ────── ≤ 1⎟    ⎟                      ⎜            ⎜⎪         as
#                    2    ⎟    ⎟                      ⎜            ⎜⎪
#               4⋅m_b     ⎟    ⎟                      ⎜            ⎜⎪
#                         ⎟    ⎟                      ⎜            ⎜⎪
# ___    ⎞                ⎟    ⎟                      ⎜            ⎜⎪       ⎛
#        ⎟                ⎟    ⎟                      ⎜            ⎜⎪       ⎜
#        ⎟                ⎟    ⎟                      ⎜⎛        2⎞ ⎜⎪ 2    2⎜
#  1  + 1⎟                ⎟    ⎟             2        ⎜⎜    4⋅mₜ ⎟ ⎜⎪π ⋅log ⎜
#        ⎟                ⎟ + 1⎟   64⋅g_{htt} ⋅m_W⋅mₜ⋅⎜⎜1 - ─────⎟⋅⎜⎨       ⎜  ╱
#        ⎠                ⎟    ⎟                      ⎜⎜       2 ⎟ ⎜⎪       ⎝╲╱
# ────────    otherwise   ⎟    ⎟                      ⎜⎝     mₕ  ⎠ ⎜⎪───────────
#      2                  ⎟    ⎟                      ⎜            ⎜⎪
# ____⎞                   ⎟    ⎟                      ⎜            ⎜⎪    ⎛
#     ⎟                   ⎟    ⎟                      ⎜            ⎜⎪    ⎜
#     ⎟                   ⎟    ⎟                      ⎜            ⎜⎪    ⎜
# + 1 ⎟                   ⎟    ⎟                      ⎜            ⎜⎪  4⋅⎜1 -
#     ⎟                   ⎟    ⎟                      ⎜            ⎜⎪    ⎜
#     ⎠                   ⎟    ⎟                      ⎜            ⎜⎪    ⎝    ╲╱
#                         ⎠    ⎠                      ⎝            ⎝⎩
# ────────────────────────────── - ─────────────────────────────────────────────
#                                                                              2
#                                                                          3⋅mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                          2
#                                         │
#                                         │
#                                         │
#                             2     ⎞    ⎞│
#   2⎛ mₕ ⎞                 mₕ      ⎟    ⎟│
# in ⎜────⎟            for ───── ≤ 1⎟    ⎟│
#    ⎝2⋅mₜ⎠                    2    ⎟    ⎟│
#                          4⋅mₜ     ⎟    ⎟│
#                                   ⎟    ⎟│
#    ___________    ⎞               ⎟    ⎟│
#   ╱         2     ⎟               ⎟    ⎟│
#  ╱      4⋅mₜ      ⎟               ⎟    ⎟│
# ╱   1 - ─────  + 1⎟               ⎟    ⎟│
#            2      ⎟               ⎟ + 1⎟│
#          mₕ       ⎠               ⎟    ⎟│
# ───────────────────    otherwise  ⎟    ⎟│
#                 2                 ⎟    ⎟│
#     ___________⎞                  ⎟    ⎟│
#    ╱         2 ⎟                  ⎟    ⎟│
#   ╱      4⋅mₜ  ⎟                  ⎟    ⎟│
#  ╱   1 - ───── ⎟                  ⎟    ⎟│
# ╱           2  ⎟                  ⎟    ⎟│
#           mₕ   ⎠                  ⎟    ⎟│
#                                   ⎠    ⎠│
# ────────────────────────────────────────│
#                                         │
#                                         │
# ──────────────────────────────────────────
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(-sp.I*np.pi))**2;#MODIFICADO#
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:160: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mWp**2)/(mS**2))))/(1-np.sqrt(1-((4*mWp**2)/(mS**2)))))*(-sp.I*np.pi))**2; #######MODIFICADO#########
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mCH**2)/(mS**2))))/(1-np.sqrt(1-((4*mCH**2)/(mS**2)))))*(-sp.I*np.pi))**2;#######MODIFICADO#########
# array([144.754176348387, 144.754174102797, 144.754172206048,
#        144.754170588601, 144.754169197602, 144.754167992250,
#        144.754166940620, 144.754166017421, 144.754165202396,
#        144.754164479160], dtype=object)

# %%
BRhWW(ghWW)
BRhWW(0.3)
# Out:
#                               ⎛
#                               ⎜
#                               ⎜
#                               ⎜                                    ⎛      4
#                               ⎜                                    ⎜60⋅m_W
#                               ⎜                                    ⎜─────── -
#                               ⎜  ⎛     4        2    ⎞    ⎛   2⎞   ⎜    4
#                          2    ⎜  ⎜6⋅m_W    9⋅m_W    3⎟    ⎜m_W ⎟   ⎝  mₕ
# 0.476371951219512⋅g_{hWW} ⋅mₕ⋅⎜- ⎜────── - ────── + ─⎟⋅log⎜────⎟ + ───────────
#                               ⎜  ⎜   4        2     2⎟    ⎜  2 ⎟
#                               ⎜  ⎝ mₕ       mₕ       ⎠    ⎝mₕ  ⎠
#                               ⎜
#                               ⎜
#                               ⎜
#                               ⎜
#                               ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                             3
#                                                                            π ⋅
#
#                  ⎛    ⎛     2    ⎞⎞
#                  ⎜  3 ⎜3⋅m_W     ⎟⎟
#                  ⎜mₕ ⋅⎜────── - 1⎟⎟
#       2    ⎞     ⎜    ⎜   2      ⎟⎟       ⎛     2    ⎞ ⎛      4         2    ⎞
# 24⋅m_W     ⎟     ⎜    ⎝ mₕ       ⎠⎟     2 ⎜  m_W     ⎟ ⎜47⋅m_W    13⋅m_W     ⎟
# ─────── + 3⎟⋅acos⎜────────────────⎟   mₕ ⋅⎜- ──── + 1⎟⋅⎜─────── - ─────── + 2⎟
#     2      ⎟     ⎜          3     ⎟       ⎜    2     ⎟ ⎜    4         2      ⎟
#   mₕ       ⎠     ⎝     2⋅m_W      ⎠       ⎝  mₕ      ⎠ ⎝  mₕ        mₕ       ⎠
# ─────────────────────────────────── - ────────────────────────────────────────
#           ___________                                       2
#          ╱     2                                       2⋅m_W
#         ╱   m_W
#        ╱    ────
#       ╱       2
#      ╱      mₕ
#    ╲╱      4     - 1
# ──────────────────────────────────────────────────────────────────────────────
#    4
# m_W
#
# ⎞
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎠
# ─
# -7.848434449577993e-10

# %%
BRhZZ(ghZZ)
BRhZZ(0.2)
# Out:
#                                        ⎛
#                                        ⎜
#                                        ⎜
#                                        ⎜                                    ⎛
#                                        ⎜                                    ⎜6
#                                        ⎜                                    ⎜─
#                                        ⎜  ⎛     4        2    ⎞    ⎛   2⎞   ⎜
#                                   2    ⎜  ⎜6⋅m_Z    9⋅m_Z    3⎟    ⎜m_Z ⎟   ⎝
# 0.119092987804878⋅\delta_Z⋅g_{HZZ} ⋅mₕ⋅⎜- ⎜────── - ────── + ─⎟⋅log⎜────⎟ + ──
#                                        ⎜  ⎜   4        2     2⎟    ⎜  2 ⎟
#                                        ⎜  ⎝ mₕ       mₕ       ⎠    ⎝mₕ  ⎠
#                                        ⎜
#                                        ⎜
#                                        ⎜
#                                        ⎜
#                                        ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                           ⎛    ⎛     2    ⎞⎞
#                           ⎜  3 ⎜3⋅m_Z     ⎟⎟
#                           ⎜mₕ ⋅⎜────── - 1⎟⎟
#      4         2    ⎞     ⎜    ⎜   2      ⎟⎟       ⎛     2    ⎞ ⎛      4
# 0⋅m_Z    24⋅m_Z     ⎟     ⎜    ⎝ mₕ       ⎠⎟     2 ⎜  m_Z     ⎟ ⎜47⋅m_Z    13⋅
# ────── - ─────── + 3⎟⋅acos⎜────────────────⎟   mₕ ⋅⎜- ──── + 1⎟⋅⎜─────── - ───
#    4         2      ⎟     ⎜          3     ⎟       ⎜    2     ⎟ ⎜    4
#  mₕ        mₕ       ⎠     ⎝     2⋅m_Z      ⎠       ⎝  mₕ      ⎠ ⎝  mₕ        m
# ──────────────────────────────────────────── - ───────────────────────────────
#                    ___________                                       2
#                   ╱     2                                       2⋅m_Z
#                  ╱   m_Z
#                 ╱    ────
#                ╱       2
#               ╱      mₕ
#             ╲╱      4     - 1
# ──────────────────────────────────────────────────────────────────────────────
#   3    4
#  π ⋅m_Z
#
#          ⎞
#          ⎟
#          ⎟
#    2    ⎞⎟
# m_Z     ⎟⎟
# ──── + 2⎟⎟
#  2      ⎟⎟
# ₕ       ⎠⎟
# ─────────⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎠
# ──────────
# -3.488193088701331e-10

# %%
BRhgg(ghtt,ghbb)
BRhgg(0.1,0.2)
# Out:
#
#                               │              ⎛               ⎛⎧
#                               │              ⎜               ⎜⎪              2
#                               │              ⎜               ⎜⎪          asin
#                               │              ⎜               ⎜⎪
#                               │              ⎜               ⎜⎪
#                               │              ⎜               ⎜⎪
#                               │              ⎜               ⎜⎪       ⎛      _
#                               │              ⎜               ⎜⎪       ⎜     ╱
#                               │              ⎜  ⎛     2    ⎞ ⎜⎪ 2    2⎜    ╱
#                               │              ⎜  ⎜4⋅m_b     ⎟ ⎜⎪π ⋅log ⎜   ╱
#                               │8⋅g_{hbb}⋅m_b⋅⎜- ⎜────── - 1⎟⋅⎜⎨       ⎜  ╱
#                               │              ⎜  ⎜   2      ⎟ ⎜⎪       ⎝╲╱
#                               │              ⎜  ⎝ mₕ       ⎠ ⎜⎪───────────────
#                               │              ⎜               ⎜⎪
#                               │              ⎜               ⎜⎪    ⎛      ____
#                               │              ⎜               ⎜⎪    ⎜     ╱
#                               │              ⎜               ⎜⎪    ⎜    ╱    4
#                               │              ⎜               ⎜⎪  4⋅⎜   ╱   - ─
#                               │              ⎜               ⎜⎪    ⎜  ╱
#                               │              ⎜               ⎜⎪    ⎝╲╱
#                         2   3 │              ⎝               ⎝⎩
# 1.90548780487805⋅\alphaₛ ⋅mₕ ⋅│───────────────────────────────────────────────
#                               │                                            2
#                               │                                          mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                            2      ⎞    ⎞                ⎛            ⎛⎧
# ⎛  mₕ ⎞                  mₕ       ⎟    ⎟                ⎜            ⎜⎪
# ⎜─────⎟             for ────── ≤ 1⎟    ⎟                ⎜            ⎜⎪
# ⎝2⋅m_b⎠                      2    ⎟    ⎟                ⎜            ⎜⎪
#                         4⋅m_b     ⎟    ⎟                ⎜            ⎜⎪
#                                   ⎟    ⎟                ⎜            ⎜⎪
# _____________    ⎞                ⎟    ⎟                ⎜            ⎜⎪
#        2         ⎟                ⎟    ⎟                ⎜            ⎜⎪
#   4⋅m_b          ⎟                ⎟    ⎟                ⎜⎛        2⎞ ⎜⎪ 2    2
# - ────── + 1  + 1⎟                ⎟    ⎟                ⎜⎜    4⋅mₜ ⎟ ⎜⎪π ⋅log
#      2           ⎟                ⎟ + 1⎟   8⋅g_{htt}⋅mₜ⋅⎜⎜1 - ─────⎟⋅⎜⎨
#    mₕ            ⎠                ⎟    ⎟                ⎜⎜       2 ⎟ ⎜⎪
# ──────────────────    otherwise   ⎟    ⎟                ⎜⎝     mₕ  ⎠ ⎜⎪───────
#                2                  ⎟    ⎟                ⎜            ⎜⎪
# __________    ⎞                   ⎟    ⎟                ⎜            ⎜⎪    ⎛
#     2         ⎟                   ⎟    ⎟                ⎜            ⎜⎪    ⎜
# ⋅m_b          ⎟                   ⎟    ⎟                ⎜            ⎜⎪    ⎜
# ───── + 1  - 1⎟                   ⎟    ⎟                ⎜            ⎜⎪  4⋅⎜
#   2           ⎟                   ⎟    ⎟                ⎜            ⎜⎪    ⎜
# mₕ            ⎠                   ⎟    ⎟                ⎜            ⎜⎪    ⎝╲╱
#                                   ⎠    ⎠                ⎝            ⎝⎩
# ──────────────────────────────────────── + ───────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                        3
#                       π
#
#                                              2
#                                 2     ⎞    ⎞│
#       2⎛ mₕ ⎞                 mₕ      ⎟    ⎟│
#   asin ⎜────⎟            for ───── ≤ 1⎟    ⎟│
#        ⎝2⋅mₜ⎠                    2    ⎟    ⎟│
#                              4⋅mₜ     ⎟    ⎟│
#                                       ⎟    ⎟│
# ⎛      ___________    ⎞               ⎟    ⎟│
# ⎜     ╱         2     ⎟               ⎟    ⎟│
# ⎜    ╱      4⋅mₜ      ⎟               ⎟    ⎟│
# ⎜   ╱   1 - ─────  + 1⎟               ⎟    ⎟│
# ⎜  ╱           2      ⎟               ⎟ + 1⎟│
# ⎝╲╱          mₕ       ⎠               ⎟    ⎟│
# ───────────────────────    otherwise  ⎟    ⎟│
#                     2                 ⎟    ⎟│
#     ___________    ⎞                  ⎟    ⎟│
#    ╱         2     ⎟                  ⎟    ⎟│
#   ╱      4⋅mₜ      ⎟                  ⎟    ⎟│
#  ╱   1 - ─────  - 1⎟                  ⎟    ⎟│
# ╱           2      ⎟                  ⎟    ⎟│
#           mₕ       ⎠                  ⎟    ⎟│
#                                       ⎠    ⎠│
# ────────────────────────────────────────────│
#      2                                      │
#    mₕ                                       │
# ──────────────────────────────────────────────
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(-sp.I*np.pi))**2;#MODIFICADO#
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# 14801864.6437227

# %%
Rbotbot(ghtt,ghbb)
Rbotbot(0.1,0.2)
# Out:
#
#                   │              ⎛               ⎛⎧
#                   │              ⎜               ⎜⎪              2⎛  mₕ ⎞
#                   │              ⎜               ⎜⎪          asin ⎜─────⎟
#                   │              ⎜               ⎜⎪               ⎝2⋅m_b⎠
#                   │              ⎜               ⎜⎪
#                   │              ⎜               ⎜⎪
#                   │              ⎜               ⎜⎪       ⎛      _____________
#                   │              ⎜               ⎜⎪       ⎜     ╱        2
#                   │              ⎜  ⎛     2    ⎞ ⎜⎪ 2    2⎜    ╱    4⋅m_b
#                   │              ⎜  ⎜4⋅m_b     ⎟ ⎜⎪π ⋅log ⎜   ╱   - ────── + 1
#                   │8⋅g_{hbb}⋅m_b⋅⎜- ⎜────── - 1⎟⋅⎜⎨       ⎜  ╱         2
#                   │              ⎜  ⎜   2      ⎟ ⎜⎪       ⎝╲╱        mₕ
#                   │              ⎜  ⎝ mₕ       ⎠ ⎜⎪───────────────────────────
#                   │              ⎜               ⎜⎪
#                   │              ⎜               ⎜⎪    ⎛      ______________
#                   │              ⎜               ⎜⎪    ⎜     ╱        2
#                   │              ⎜               ⎜⎪    ⎜    ╱    4⋅m_b
#                   │              ⎜               ⎜⎪  4⋅⎜   ╱   - ────── + 1  -
#                   │              ⎜               ⎜⎪    ⎜  ╱         2
#                   │              ⎜               ⎜⎪    ⎝╲╱        mₕ
#            2    2 │              ⎝               ⎝⎩
# 4.0⋅g_{hbb} ⋅m_W ⋅│───────────────────────────────────────────────────────────
#                   │                                            2
#                   │                                          mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#                   │         ⎛               ⎛⎧
#                   │         ⎜               ⎜⎪              2⎛  mₕ ⎞
#                   │         ⎜               ⎜⎪          asin ⎜─────⎟
#                   │         ⎜               ⎜⎪               ⎝2⋅m_b⎠
#                   │         ⎜               ⎜⎪
#                   │         ⎜               ⎜⎪
#                   │         ⎜               ⎜⎪       ⎛      ______________
#                   │         ⎜               ⎜⎪       ⎜     ╱        2
#                   │         ⎜  ⎛     2    ⎞ ⎜⎪ 2    2⎜    ╱    4⋅m_b
#                   │       2 ⎜  ⎜4⋅m_b     ⎟ ⎜⎪π ⋅log ⎜   ╱   - ────── + 1  + 1
#                   │4⋅g⋅m_b ⋅⎜- ⎜────── - 1⎟⋅⎜⎨       ⎜  ╱         2
#                   │         ⎜  ⎜   2      ⎟ ⎜⎪       ⎝╲╱        mₕ
#                   │         ⎜  ⎝ mₕ       ⎠ ⎜⎪────────────────────────────────
#                   │         ⎜               ⎜⎪                              2
#                   │         ⎜               ⎜⎪    ⎛      ______________    ⎞
#                   │         ⎜               ⎜⎪    ⎜     ╱        2         ⎟
#                   │         ⎜               ⎜⎪    ⎜    ╱    4⋅m_b          ⎟
#                   │         ⎜               ⎜⎪  4⋅⎜   ╱   - ────── + 1  - 1⎟
#                   │         ⎜               ⎜⎪    ⎜  ╱         2           ⎟
#                   │         ⎜               ⎜⎪    ⎝╲╱        mₕ            ⎠
#            2    2 │         ⎝               ⎝⎩
#           g ⋅m_b ⋅│───────────────────────────────────────────────────────────
#                   │                                           2
#                   │                                     m_W⋅mₕ
#
#
#                2      ⎞    ⎞                ⎛            ⎛⎧
#              mₕ       ⎟    ⎟                ⎜            ⎜⎪             2⎛ mₕ
#         for ────── ≤ 1⎟    ⎟                ⎜            ⎜⎪         asin ⎜────
#                  2    ⎟    ⎟                ⎜            ⎜⎪              ⎝2⋅mₜ
#             4⋅m_b     ⎟    ⎟                ⎜            ⎜⎪
#                       ⎟    ⎟                ⎜            ⎜⎪
# _    ⎞                ⎟    ⎟                ⎜            ⎜⎪       ⎛      _____
#      ⎟                ⎟    ⎟                ⎜            ⎜⎪       ⎜     ╱
#      ⎟                ⎟    ⎟                ⎜⎛        2⎞ ⎜⎪ 2    2⎜    ╱
#   + 1⎟                ⎟    ⎟                ⎜⎜    4⋅mₜ ⎟ ⎜⎪π ⋅log ⎜   ╱   1 -
#      ⎟                ⎟ + 1⎟   8⋅g_{htt}⋅mₜ⋅⎜⎜1 - ─────⎟⋅⎜⎨       ⎜  ╱
#      ⎠                ⎟    ⎟                ⎜⎜       2 ⎟ ⎜⎪       ⎝╲╱
# ──────    otherwise   ⎟    ⎟                ⎜⎝     mₕ  ⎠ ⎜⎪───────────────────
#    2                  ⎟    ⎟                ⎜            ⎜⎪
#   ⎞                   ⎟    ⎟                ⎜            ⎜⎪    ⎛      ________
#   ⎟                   ⎟    ⎟                ⎜            ⎜⎪    ⎜     ╱
#   ⎟                   ⎟    ⎟                ⎜            ⎜⎪    ⎜    ╱      4⋅m
#  1⎟                   ⎟    ⎟                ⎜            ⎜⎪  4⋅⎜   ╱   1 - ───
#   ⎟                   ⎟    ⎟                ⎜            ⎜⎪    ⎜  ╱
#   ⎠                   ⎟    ⎟                ⎜            ⎜⎪    ⎝╲╱          mₕ
#                       ⎠    ⎠                ⎝            ⎝⎩
# ──────────────────────────── + ───────────────────────────────────────────────
#                                                                        2
#                                                                      mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#           2      ⎞    ⎞           ⎛            ⎛⎧
#         mₕ       ⎟    ⎟           ⎜            ⎜⎪             2⎛ mₕ ⎞
#    for ────── ≤ 1⎟    ⎟           ⎜            ⎜⎪         asin ⎜────⎟
#             2    ⎟    ⎟           ⎜            ⎜⎪              ⎝2⋅mₜ⎠
#        4⋅m_b     ⎟    ⎟           ⎜            ⎜⎪
#                  ⎟    ⎟           ⎜            ⎜⎪
# ⎞                ⎟    ⎟           ⎜            ⎜⎪       ⎛      ___________
# ⎟                ⎟    ⎟           ⎜            ⎜⎪       ⎜     ╱         2
# ⎟                ⎟    ⎟           ⎜⎛        2⎞ ⎜⎪ 2    2⎜    ╱      4⋅mₜ
# ⎟                ⎟    ⎟         2 ⎜⎜    4⋅mₜ ⎟ ⎜⎪π ⋅log ⎜   ╱   1 - ─────  + 1
# ⎟                ⎟ + 1⎟   4⋅g⋅mₜ ⋅⎜⎜1 - ─────⎟⋅⎜⎨       ⎜  ╱           2
# ⎠                ⎟    ⎟           ⎜⎜       2 ⎟ ⎜⎪       ⎝╲╱          mₕ
# ─    otherwise   ⎟    ⎟           ⎜⎝     mₕ  ⎠ ⎜⎪─────────────────────────────
#                  ⎟    ⎟           ⎜            ⎜⎪                           2
#                  ⎟    ⎟           ⎜            ⎜⎪    ⎛      ___________    ⎞
#                  ⎟    ⎟           ⎜            ⎜⎪    ⎜     ╱         2     ⎟
#                  ⎟    ⎟           ⎜            ⎜⎪    ⎜    ╱      4⋅mₜ      ⎟
#                  ⎟    ⎟           ⎜            ⎜⎪  4⋅⎜   ╱   1 - ─────  - 1⎟
#                  ⎟    ⎟           ⎜            ⎜⎪    ⎜  ╱           2      ⎟
#                  ⎟    ⎟           ⎜            ⎜⎪    ⎝╲╱          mₕ       ⎠
#                  ⎠    ⎠           ⎝            ⎝⎩
# ─────────────────────── + ────────────────────────────────────────────────────
#                                                                  2
#                                                            m_W⋅mₕ
#
#                                  2
#                     2     ⎞    ⎞│
# ⎞                 mₕ      ⎟    ⎟│
# ⎟            for ───── ≤ 1⎟    ⎟│
# ⎠                    2    ⎟    ⎟│
#                  4⋅mₜ     ⎟    ⎟│
#                           ⎟    ⎟│
# ______    ⎞               ⎟    ⎟│
#     2     ⎟               ⎟    ⎟│
# 4⋅mₜ      ⎟               ⎟    ⎟│
# ─────  + 1⎟               ⎟    ⎟│
#    2      ⎟               ⎟ + 1⎟│
#  mₕ       ⎠               ⎟    ⎟│
# ───────────    otherwise  ⎟    ⎟│
#         2                 ⎟    ⎟│
# ___    ⎞                  ⎟    ⎟│
#  2     ⎟                  ⎟    ⎟│
# ₜ      ⎟                  ⎟    ⎟│
# ──  - 1⎟                  ⎟    ⎟│
# 2      ⎟                  ⎟    ⎟│
#        ⎠                  ⎟    ⎟│
#                           ⎠    ⎠│
# ────────────────────────────────│
#                                 │
#                                 │
# ──────────────────────────────────
#                        2
#           2     ⎞    ⎞│
#         mₕ      ⎟    ⎟│
#    for ───── ≤ 1⎟    ⎟│
#            2    ⎟    ⎟│
#        4⋅mₜ     ⎟    ⎟│
#                 ⎟    ⎟│
# ⎞               ⎟    ⎟│
# ⎟               ⎟    ⎟│
# ⎟               ⎟    ⎟│
# ⎟               ⎟    ⎟│
# ⎟               ⎟ + 1⎟│
# ⎠               ⎟    ⎟│
# ─    otherwise  ⎟    ⎟│
#                 ⎟    ⎟│
#                 ⎟    ⎟│
#                 ⎟    ⎟│
#                 ⎟    ⎟│
#                 ⎟    ⎟│
#                 ⎟    ⎟│
#                 ⎟    ⎟│
#                 ⎠    ⎠│
# ──────────────────────│
#                       │
#                       │
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2)))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2))))*(-sp.I*np.pi))**2;#MODIFICADO#
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# 19168.7821861366

# %%
ghtautau = sp.symbols(r'g_{h\tau\tau}',real=True)
Rtata(ghtt,ghbb,ghtautau)
Rtata(0.1,0.2,0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-288863f6feee> in <module>
#       1 ghtautau = sp.symbols(r'g_{h\tau\tau}',real=True)
# ----> 2 Rtata(ghtt,ghbb,ghtautau)
#       3 Rtata(0.1,0.2,0.01)
#
# NameError: name 'Rtata' is not defined

# %%
RWW(ghtt,ghbb,ghWW)
RWW(0.1,0.2,0.01)

# %%
RZZ(ghtt,ghbb,ghZZ)
RZZ(0.1,0.2,0.01)

# %%
Rgaga(ghtt,ghbb,ghWW,gCH,mCH).simplify()
Rgaga(0.1,0.2,0.3,0.001,200)

# %%
Rgg(ghtt,ghbb)
